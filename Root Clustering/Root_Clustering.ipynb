# %%
# !jupyter nbconvert --to script Root_Clustering.ipynb
# Out:
# [NbConvertApp] Converting notebook Root_Clustering.ipynb to script
# [NbConvertApp] Writing 34729 bytes to Root_Clustering.py

# %%
# ✅ STEP 1: Fresh clone of the repo (avoid nesting errors)
# !rm -rf quran_analysis
# !git clone https://github.com/Diqzi-D/quran_analysis.git
# %cd quran_analysis/Root\ Clustering

# ✅ STEP 2: Smart download helper
from pathlib import Path

def smart_download(path, url):
    path = Path(path)
    if not path.exists():
        print(f"📥 Downloading: {path.name}")
        path.parent.mkdir(parents=True, exist_ok=True)
        # !wget -q "{url}" -O "{path}"
        print(f"✅ Downloaded to: {path}")
    else:
        print(f"✅ Already exists: {path}")

# ✅ STEP 3: Smart download any large file needed
# (Only use this block if your current notebook depends on a large file)
# Example:
# smart_download(
#     "Data/merged_quran_data.csv",
#     "https://github.com/Diqzi-D/quran_analysis/releases/download/v1.0/merged_quran_data.csv"
# )

# ✅ STEP 4: Confirm working directory and contents
from os import getcwd
print("📂 Current directory:", getcwd())
# !ls -l
# Out:
# Cloning into 'quran_analysis'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 114 (delta 3), reused 3 (delta 0), pack-reused 100 (from 3)
# Receiving objects: 100% (114/114), 147.69 MiB | 18.30 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Updating files: 100% (64/64), done.
# /content/quran_analysis/Root Clustering
# 📂 Current directory: /content/quran_analysis/Root Clustering
# total 1024
# drwxr-xr-x 2 root root    4096 Apr  8 13:16 Data
# drwxr-xr-x 2 root root    4096 Apr  8 13:16 Output
# -rw-r--r-- 1 root root 1036963 Apr  8 13:16 Root_Clustering.ipynb

# %%
# 📦 Core Libraries
# !pip install numpy pandas matplotlib seaborn scikit-learn

# 📊 NLP + Arabic Tools
# !pip install arabic-reshaper python-bidi adjustText

# 🧠 Embedding / Clustering / Visualization
# !pip install umap-learn

# 🔽 For Google Drive file download (optional, for big files)
# !pip install gdown
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting arabic-reshaper
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl.metadata (12 kB)
# Collecting python-bidi
#   Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from adjustText) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from adjustText) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from adjustText) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)
# Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 10.5 MB/s eta 0:00:00
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: python-bidi, arabic-reshaper, adjustText
# Successfully installed adjustText-1.3.0 arabic-reshaper-3.0.0 python-bidi-0.6.6
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.6.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->umap-learn) (3.6.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# Helper to reshape Arabic for correct visualization
import arabic_reshaper
from bidi.algorithm import get_display

def reshape_arabic(text):
    reshaped = arabic_reshaper.reshape(text)
    return get_display(reshaped)

# %%
# StopWord List

import json

# --- Load Stop Words ---
stop_words_file = "Data/stop_words_arabic.txt"  # Replace with your actual path
with open(stop_words_file, "r", encoding="utf-8") as file:
    stop_words = set(word.strip() for word in file if word.strip())

# --- Load Normalized Unified Quran Data ---
input_file = "Data/normalized_unified_quran_data.json"
with open(input_file, "r", encoding="utf-8") as f:
    normalized_data = json.load(f)

# --- Function to Filter Stopwords from Roots ---
def filter_stopwords_in_roots(data, stop_words):
    """
    For each verse, filters out stop words from the 'arabic_roots' field.
    Adds two new keys:
      - 'filtered_roots': roots that are not stopwords.
      - 'filtered_out_roots': roots that were filtered out.
    """
    filtered_data = []
    for verse in data:
        # Retrieve roots; default to an empty list if missing
        roots = verse.get("arabic_roots", [])
        filtered_roots = [root for root in roots if root not in stop_words]
        filtered_out = [root for root in roots if root in stop_words]
        verse["filtered_roots"] = filtered_roots
        verse["filtered_out_roots"] = filtered_out
        filtered_data.append(verse)
    return filtered_data

# --- Apply Stopword Filtering ---
filtered_data = filter_stopwords_in_roots(normalized_data, stop_words)

# --- Save the Filtered Data ---
output_file = "Data/filtered_unified_quran_data.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(filtered_data, f, ensure_ascii=False, indent=4)

print("✅ Filtered data saved to:", output_file)
# Out:
# ✅ Filtered data saved to: Data/filtered_unified_quran_data.json

# %%
# All Roots Co-Occurrence

import json
from collections import Counter, defaultdict

# --- Load the Normalized Unified Data ---
input_file = "Data/filtered_unified_quran_data.json"
with open(input_file, "r", encoding="utf-8") as file:
    normalized_data = json.load(file)

# --- Function to Perform Co-Occurrence Analysis on Roots ---
def co_occurrence_analysis(data, threshold=2, key="filtered_roots"):
    """
    Analyzes the co-occurrence of roots within each verse.

    Parameters:
      data (list): List of verse entries.
      threshold (int): Minimum number of occurrences for a pair to be included.
      key (str): The key in each verse that holds the list of roots (default "filtered_roots").

    Returns:
      dict: A dictionary mapping each root to a Counter of co-occurring roots.
    """
    cooccurrence_counts = defaultdict(Counter)

    # Build the co-occurrence matrix
    for verse in data:
        # Retrieve the list of roots safely; default to empty list if key is missing.
        roots = verse.get(key, [])
        if not isinstance(roots, list):
            continue
        # For each pair of distinct roots in the verse, update the count
        for i, root1 in enumerate(roots):
            for j, root2 in enumerate(roots):
                if i != j:
                    cooccurrence_counts[root1][root2] += 1

    # Apply the threshold filter: keep only pairs with count >= threshold
    filtered_cooccurrence_counts = {
        root: {
            co_root: count
            for co_root, count in connections.items() if count >= threshold
        }
        for root, connections in cooccurrence_counts.items()
    }
    return filtered_cooccurrence_counts

# --- Perform Co-Occurrence Analysis ---
filtered_cooccurrence_counts = co_occurrence_analysis(normalized_data, threshold=2, key="filtered_roots")

# --- Save the Filtered Co-Occurrence Data to JSON ---
output_file = "Data/filtered_cooccurrence_data.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(filtered_cooccurrence_counts, f, ensure_ascii=False, indent=4)

print(f"\n✅ Co-occurrence analysis saved to {output_file}")

# --- Print a Sorted Sample of Co-Occurrence Results ---
print("\n🔹 First 5 Co-Occurrence Results:")
for root, cooccurrences in list(filtered_cooccurrence_counts.items())[:5]:
    print(f"Root: {root}")
    sorted_cooccurrences = sorted(cooccurrences.items(), key=lambda x: x[1], reverse=True)
    for co_root, count in sorted_cooccurrences:
        print(f"  ↪ Co-occurs with: {co_root}, Count: {count}")
# Out:
# ✅ Co-occurrence analysis saved to Data/filtered_cooccurrence_data.json
#
# 🔹 First 5 Co-Occurrence Results:
# Root: سمو
#   ↪ Co-occurs with: اله, Count: 319
#   ↪ Co-occurs with: ارض, Count: 263
#   ↪ Co-occurs with: علم, Count: 111
#   ↪ Co-occurs with: قول, Count: 110
#   ↪ Co-occurs with: اللذ, Count: 98
#   ↪ Co-occurs with: كون, Count: 95
#   ↪ Co-occurs with: خلق, Count: 93
#   ↪ Co-occurs with: شيا, Count: 82
#   ↪ Co-occurs with: ربب, Count: 77
#   ↪ Co-occurs with: هو, Count: 75
#   ↪ Co-occurs with: سمو, Count: 64
#   ↪ Co-occurs with: كلل, Count: 64
#   ↪ Co-occurs with: نزل, Count: 59
#   ↪ Co-occurs with: بين, Count: 56
#   ↪ Co-occurs with: ملك, Count: 47
#   ↪ Co-occurs with: راي, Count: 41
#   ↪ Co-occurs with: قوم, Count: 38
#   ↪ Co-occurs with: موه, Count: 35
#   ↪ Co-occurs with: ايا, Count: 34
#   ↪ Co-occurs with: اتي, Count: 33
#   ↪ Co-occurs with: اجل, Count: 33
#   ↪ Co-occurs with: يوم, Count: 33
#   ↪ Co-occurs with: جعل, Count: 32
#   ↪ Co-occurs with: قدر, Count: 32
#   ↪ Co-occurs with: امن, Count: 31
#   ↪ Co-occurs with: حقق, Count: 28
#   ↪ Co-occurs with: كتب, Count: 27
#   ↪ Co-occurs with: سبح, Count: 26
#   ↪ Co-occurs with: امر, Count: 26
#   ↪ Co-occurs with: ذكر, Count: 25
#   ↪ Co-occurs with: نوس, Count: 25
#   ↪ Co-occurs with: رسل, Count: 25
#   ↪ Co-occurs with: غفر, Count: 24
#   ↪ Co-occurs with: خرج, Count: 23
#   ↪ Co-occurs with: بعد, Count: 22
#   ↪ Co-occurs with: رحم, Count: 21
#   ↪ Co-occurs with: سخر, Count: 21
#   ↪ Co-occurs with: عبد, Count: 21
#   ↪ Co-occurs with: كفر, Count: 20
#   ↪ Co-occurs with: نهر, Count: 20
#   ↪ Co-occurs with: حيي, Count: 20
#   ↪ Co-occurs with: موت, Count: 19
#   ↪ Co-occurs with: اخر, Count: 19
#   ↪ Co-occurs with: رزق, Count: 18
#   ↪ Co-occurs with: غير, Count: 18
#   ↪ Co-occurs with: عمل, Count: 18
#   ↪ Co-occurs with: حكم, Count: 18
#   ↪ Co-occurs with: شرك, Count: 18
#   ↪ Co-occurs with: ظلم, Count: 17
#   ↪ Co-occurs with: انتم, Count: 17
#   ↪ Co-occurs with: سوي, Count: 17
#   ↪ Co-occurs with: دون, Count: 17
#   ↪ Co-occurs with: ولي, Count: 17
#   ↪ Co-occurs with: ليل, Count: 17
#   ↪ Co-occurs with: شهد, Count: 17
#   ↪ Co-occurs with: دعو, Count: 17
#   ↪ Co-occurs with: عزز, Count: 17
#   ↪ Co-occurs with: حمد, Count: 16
#   ↪ Co-occurs with: نبا, Count: 15
#   ↪ Co-occurs with: عذب, Count: 15
#   ↪ Co-occurs with: خلف, Count: 15
#   ↪ Co-occurs with: نفس, Count: 15
#   ↪ Co-occurs with: مثل, Count: 15
#   ↪ Co-occurs with: دنو, Count: 14
#   ↪ Co-occurs with: اخذ, Count: 14
#   ↪ Co-occurs with: جري, Count: 14
#   ↪ Co-occurs with: فطر, Count: 14
#   ↪ Co-occurs with: كثر, Count: 14
#   ↪ Co-occurs with: غيب, Count: 13
#   ↪ Co-occurs with: وقي, Count: 13
#   ↪ Co-occurs with: نور, Count: 13
#   ↪ Co-occurs with: نظر, Count: 13
#   ↪ Co-occurs with: حسن, Count: 13
#   ↪ Co-occurs with: عرض, Count: 12
#   ↪ Co-occurs with: قبل, Count: 12
#   ↪ Co-occurs with: سال, Count: 12
#   ↪ Co-occurs with: نبت, Count: 12
#   ↪ Co-occurs with: بصر, Count: 12
#   ↪ Co-occurs with: كبر, Count: 11
#   ↪ Co-occurs with: بشر, Count: 11
#   ↪ Co-occurs with: سلط, Count: 11
#   ↪ Co-occurs with: نعم, Count: 11
#   ↪ Co-occurs with: عرش, Count: 11
#   ↪ Co-occurs with: زين, Count: 11
#   ↪ Co-occurs with: جمع, Count: 10
#   ↪ Co-occurs with: سبع, Count: 10
#   ↪ Co-occurs with: عظم, Count: 10
#   ↪ Co-occurs with: عمما, Count: 10
#   ↪ Co-occurs with: دبب, Count: 10
#   ↪ Co-occurs with: روح, Count: 10
#   ↪ Co-occurs with: دين, Count: 10
#   ↪ Co-occurs with: طوع, Count: 10
#   ↪ Co-occurs with: مريم, Count: 10
#   ↪ Co-occurs with: بنو, Count: 10
#   ↪ Co-occurs with: رجع, Count: 10
#   ↪ Co-occurs with: جيا, Count: 10
#   ↪ Co-occurs with: هدي, Count: 10
#   ↪ Co-occurs with: قمر, Count: 10
#   ↪ Co-occurs with: قضي, Count: 9
#   ↪ Co-occurs with: علو, Count: 9
#   ↪ Co-occurs with: صور, Count: 9
#   ↪ Co-occurs with: شمس, Count: 9
#   ↪ Co-occurs with: ابو, Count: 9
#   ↪ Co-occurs with: صبح, Count: 9
#   ↪ Co-occurs with: نصر, Count: 8
#   ↪ Co-occurs with: نفع, Count: 8
#   ↪ Co-occurs with: سلم, Count: 8
#   ↪ Co-occurs with: جنن, Count: 8
#   ↪ Co-occurs with: خير, Count: 8
#   ↪ Co-occurs with: خبر, Count: 8
#   ↪ Co-occurs with: غني, Count: 8
#   ↪ Co-occurs with: رود, Count: 8
#   ↪ Co-occurs with: ولج, Count: 8
#   ↪ Co-occurs with: ستت, Count: 8
#   ↪ Co-occurs with: برك, Count: 8
#   ↪ Co-occurs with: ظنن, Count: 8
#   ↪ Co-occurs with: اذن, Count: 7
#   ↪ Co-occurs with: بنا, Count: 7
#   ↪ Co-occurs with: ثمر, Count: 7
#   ↪ Co-occurs with: سجد, Count: 7
#   ↪ Co-occurs with: عقل, Count: 7
#   ↪ Co-occurs with: شفع, Count: 7
#   ↪ Co-occurs with: اول, Count: 7
#   ↪ Co-occurs with: لقي, Count: 7
#   ↪ Co-occurs with: اكل, Count: 7
#   ↪ Co-occurs with: مسك, Count: 7
#   ↪ Co-occurs with: جزي, Count: 7
#   ↪ Co-occurs with: سوع, Count: 7
#   ↪ Co-occurs with: صدق, Count: 6
#   ↪ Co-occurs with: وجه, Count: 6
#   ↪ Co-occurs with: حرم, Count: 6
#   ↪ Co-occurs with: فلك, Count: 6
#   ↪ Co-occurs with: بحر, Count: 6
#   ↪ Co-occurs with: بثث, Count: 6
#   ↪ Co-occurs with: سحب, Count: 6
#   ↪ Co-occurs with: يدي, Count: 6
#   ↪ Co-occurs with: حفظ, Count: 6
#   ↪ Co-occurs with: ضلل, Count: 6
#   ↪ Co-occurs with: ضرر, Count: 6
#   ↪ Co-occurs with: فعل, Count: 6
#   ↪ Co-occurs with: خفي, Count: 6
#   ↪ Co-occurs with: كلم, Count: 6
#   ↪ Co-occurs with: فضل, Count: 6
#   ↪ Co-occurs with: فكر, Count: 6
#   ↪ Co-occurs with: نفق, Count: 6
#   ↪ Co-occurs with: يقن, Count: 6
#   ↪ Co-occurs with: ظهر, Count: 6
#   ↪ Co-occurs with: فتح, Count: 6
#   ↪ Co-occurs with: تبع, Count: 6
#   ↪ Co-occurs with: ذهب, Count: 6
#   ↪ Co-occurs with: وعد, Count: 6
#   ↪ Co-occurs with: شدد, Count: 6
#   ↪ Co-occurs with: شجر, Count: 6
#   ↪ Co-occurs with: بعض, Count: 6
#   ↪ Co-occurs with: كسف, Count: 6
#   ↪ Co-occurs with: زوج, Count: 6
#   ↪ Co-occurs with: حوط, Count: 5
#   ↪ Co-occurs with: ادم, Count: 5
#   ↪ Co-occurs with: بدو, Count: 5
#   ↪ Co-occurs with: فسق, Count: 5
#   ↪ Co-occurs with: ولد, Count: 5
#   ↪ Co-occurs with: اللت, Count: 5
#   ↪ Co-occurs with: صرف, Count: 5
#   ↪ Co-occurs with: عدل, Count: 5
#   ↪ Co-occurs with: ريب, Count: 5
#   ↪ Co-occurs with: حسب, Count: 5
#   ↪ Co-occurs with: صدر, Count: 5
#   ↪ Co-occurs with: انث, Count: 5
#   ↪ Co-occurs with: عيس, Count: 5
#   ↪ Co-occurs with: بغي, Count: 5
#   ↪ Co-occurs with: بطل, Count: 5
#   ↪ Co-occurs with: وكل, Count: 5
#   ↪ Co-occurs with: اهل, Count: 5
#   ↪ Co-occurs with: ذنب, Count: 5
#   ↪ Co-occurs with: كسب, Count: 5
#   ↪ Co-occurs with: طعم, Count: 5
#   ↪ Co-occurs with: وفي, Count: 5
#   ↪ Co-occurs with: هوي, Count: 5
#   ↪ Co-occurs with: ثقل, Count: 5
#   ↪ Co-occurs with: دبر, Count: 5
#   ↪ Co-occurs with: سمع, Count: 5
#   ↪ Co-occurs with: رفع, Count: 5
#   ↪ Co-occurs with: ضرب, Count: 5
#   ↪ Co-occurs with: سبل, Count: 5
#   ↪ Co-occurs with: عرج, Count: 5
#   ↪ Co-occurs with: سقط, Count: 5
#   ↪ Co-occurs with: صلو, Count: 5
#   ↪ Co-occurs with: شقق, Count: 5
#   ↪ Co-occurs with: جبل, Count: 5
#   ↪ Co-occurs with: هي, Count: 5
#   ↪ Co-occurs with: رجز, Count: 4
#   ↪ Co-occurs with: قلب, Count: 4
#   ↪ Co-occurs with: ابي, Count: 4
#   ↪ Co-occurs with: ملل, Count: 4
#   ↪ Co-occurs with: احد, Count: 4
#   ↪ Co-occurs with: وضع, Count: 4
#   ↪ Co-occurs with: ذرر, Count: 4
#   ↪ Co-occurs with: شطن, Count: 4
#   ↪ Co-occurs with: مسح, Count: 4
#   ↪ Co-occurs with: عدد, Count: 4
#   ↪ Co-occurs with: وحد, Count: 4
#   ↪ Co-occurs with: ماذا, Count: 4
#   ↪ Co-occurs with: طيب, Count: 4
#   ↪ Co-occurs with: حبب, Count: 4
#   ↪ Co-occurs with: صير, Count: 4
#   ↪ Co-occurs with: بيت, Count: 4
#   ↪ Co-occurs with: ميد, Count: 4
#   ↪ Co-occurs with: عود, Count: 4
#   ↪ Co-occurs with: درر, Count: 4
#   ↪ Co-occurs with: خسر, Count: 4
#   ↪ Co-occurs with: بعث, Count: 4
#   ↪ Co-occurs with: نفخ, Count: 4
#   ↪ Co-occurs with: فصل, Count: 4
#   ↪ Co-occurs with: وحي, Count: 4
#   ↪ Co-occurs with: جدل, Count: 4
#   ↪ Co-occurs with: بوب, Count: 4
#   ↪ Co-occurs with: عسي, Count: 4
#   ↪ Co-occurs with: رسو, Count: 4
#   ↪ Co-occurs with: قتل, Count: 4
#   ↪ Co-occurs with: نذر, Count: 4
#   ↪ Co-occurs with: قوي, Count: 4
#   ↪ Co-occurs with: عمد, Count: 4
#   ↪ Co-occurs with: اصل, Count: 4
#   ↪ Co-occurs with: صدد, Count: 4
#   ↪ Co-occurs with: فرع, Count: 4
#   ↪ Co-occurs with: كود, Count: 4
#   ↪ Co-occurs with: كرم, Count: 4
#   ↪ Co-occurs with: لون, Count: 4
#   ↪ Co-occurs with: كور, Count: 4
#   ↪ Co-occurs with: صوب, Count: 3
#   ↪ Co-occurs with: برق, Count: 3
#   ↪ Co-occurs with: صعق, Count: 3
#   ↪ Co-occurs with: كتم, Count: 3
#   ↪ Co-occurs with: بدل, Count: 3
#   ↪ Co-occurs with: خوف, Count: 3
#   ↪ Co-occurs with: رضو, Count: 3
#   ↪ Co-occurs with: نوم, Count: 3
#   ↪ Co-occurs with: وسع, Count: 3
#   ↪ Co-occurs with: رجل, Count: 3
#   ↪ Co-occurs with: صغر, Count: 3
#   ↪ Co-occurs with: قرب, Count: 3
#   ↪ Co-occurs with: كره, Count: 3
#   ↪ Co-occurs with: ورث, Count: 3
#   ↪ Co-occurs with: كفي, Count: 3
#   ↪ Co-occurs with: موس, Count: 3
#   ↪ Co-occurs with: جهر, Count: 3
#   ↪ Co-occurs with: ثلث, Count: 3
#   ↪ Co-occurs with: حلل, Count: 3
#   ↪ Co-occurs with: هلك, Count: 3
#   ↪ Co-occurs with: امم, Count: 3
#   ↪ Co-occurs with: شهر, Count: 3
#   ↪ Co-occurs with: قلد, Count: 3
#   ↪ Co-occurs with: انت, Count: 3
#   ↪ Co-occurs with: سرر, Count: 3
#   ↪ Co-occurs with: زيت, Count: 3
#   ↪ Co-occurs with: شبه, Count: 3
#   ↪ Co-occurs with: رجس, Count: 3
#   ↪ Co-occurs with: زعم, Count: 3
#   ↪ Co-occurs with: كذب, Count: 3
#   ↪ Co-occurs with: وقع, Count: 3
#   ↪ Co-occurs with: ربع, Count: 3
#   ↪ Co-occurs with: قرا, Count: 3
#   ↪ Co-occurs with: توب, Count: 3
#   ↪ Co-occurs with: متع, Count: 3
#   ↪ Co-occurs with: زيد, Count: 3
#   ↪ Co-occurs with: ظلل, Count: 3
#   ↪ Co-occurs with: حمل, Count: 3
#   ↪ Co-occurs with: زبد, Count: 3
#   ↪ Co-occurs with: شكك, Count: 3
#   ↪ Co-occurs with: علن, Count: 3
#   ↪ Co-occurs with: برج, Count: 3
#   ↪ Co-occurs with: طير, Count: 3
#   ↪ Co-occurs with: رقي, Count: 3
#   ↪ Co-occurs with: سبق, Count: 3
#   ↪ Co-occurs with: طوي, Count: 3
#   ↪ Co-occurs with: بدا, Count: 3
#   ↪ Co-occurs with: بلغ, Count: 3
#   ↪ Co-occurs with: بهج, Count: 3
#   ↪ Co-occurs with: سبب, Count: 3
#   ↪ Co-occurs with: شعر, Count: 3
#   ↪ Co-occurs with: بلي, Count: 3
#   ↪ Co-occurs with: خسف, Count: 3
#   ↪ Co-occurs with: نوب, Count: 3
#   ↪ Co-occurs with: جند, Count: 3
#   ↪ Co-occurs with: مور, Count: 3
#   ↪ Co-occurs with: نفذ, Count: 3
#   ↪ Co-occurs with: فرش, Count: 2
#   ↪ Co-occurs with: ندد, Count: 2
#   ↪ Co-occurs with: دخل, Count: 2
#   ↪ Co-occurs with: قنت, Count: 2
#   ↪ Co-occurs with: بدع, Count: 2
#   ↪ Co-occurs with: شطر, Count: 2
#   ↪ Co-occurs with: غفل, Count: 2
#   ↪ Co-occurs with: وسن, Count: 2
#   ↪ Co-occurs with: كرس, Count: 2
#   ↪ Co-occurs with: اود, Count: 2
#   ↪ Co-occurs with: دور, Count: 2
#   ↪ Co-occurs with: جنح, Count: 2
#   ↪ Co-occurs with: بيع, Count: 2
#   ↪ Co-occurs with: رجم, Count: 2
#   ↪ Co-occurs with: سرع, Count: 2
#   ↪ Co-occurs with: بخل, Count: 2
#   ↪ Co-occurs with: لبب, Count: 2
#   ↪ Co-occurs with: جنب, Count: 2
#   ↪ Co-occurs with: وصي, Count: 2
#   ↪ Co-occurs with: عجل, Count: 2
#   ↪ Co-occurs with: جرح, Count: 2
#   ↪ Co-occurs with: كم, Count: 2
#   ↪ Co-occurs with: قرن, Count: 2
#   ↪ Co-occurs with: مكن, Count: 2
#   ↪ Co-occurs with: تحت, Count: 2
#   ↪ Co-occurs with: جهل, Count: 2
#   ↪ Co-occurs with: ابر, Count: 2
#   ↪ Co-occurs with: حنف, Count: 2
#   ↪ Co-occurs with: خضر, Count: 2
#   ↪ Co-occurs with: ركب, Count: 2
#   ↪ Co-occurs with: طلع, Count: 2
#   ↪ Co-occurs with: حرج, Count: 2
#   ↪ Co-occurs with: كاننما, Count: 2
#   ↪ Co-occurs with: صعد, Count: 2
#   ↪ Co-occurs with: حجر, Count: 2
#   ↪ Co-occurs with: فري, Count: 2
#   ↪ Co-occurs with: جمل, Count: 2
#   ↪ Co-occurs with: جرم, Count: 2
#   ↪ Co-occurs with: غشي, Count: 2
#   ↪ Co-occurs with: نجم, Count: 2
#   ↪ Co-occurs with: غضب, Count: 2
#   ↪ Co-occurs with: قري, Count: 2
#   ↪ Co-occurs with: وذر, Count: 2
#   ↪ Co-occurs with: لحد, Count: 2
#   ↪ Co-occurs with: حدث, Count: 2
#   ↪ Co-occurs with: بغت, Count: 2
#   ↪ Co-occurs with: طهر, Count: 2
#   ↪ Co-occurs with: ربط, Count: 2
#   ↪ Co-occurs with: ثبت, Count: 2
#   ↪ Co-occurs with: قدم, Count: 2
#   ↪ Co-occurs with: ثني, Count: 2
#   ↪ Co-occurs with: عشر, Count: 2
#   ↪ Co-occurs with: كفف, Count: 2
#   ↪ Co-occurs with: خلط, Count: 2
#   ↪ Co-occurs with: زخرف, Count: 2
#   ↪ Co-occurs with: حصد, Count: 2
#   ↪ Co-occurs with: شان, Count: 2
#   ↪ Co-occurs with: عزب, Count: 2
#   ↪ Co-occurs with: سحر, Count: 2
#   ↪ Co-occurs with: خلد, Count: 2
#   ↪ Co-occurs with: دوم, Count: 2
#   ↪ Co-occurs with: لما, Count: 2
#   ↪ Co-occurs with: غدو, Count: 2
#   ↪ Co-occurs with: قهر, Count: 2
#   ↪ Co-occurs with: سيل, Count: 2
#   ↪ Co-occurs with: ربو, Count: 2
#   ↪ Co-occurs with: وقد, Count: 2
#   ↪ Co-occurs with: ويل, Count: 2
#   ↪ Co-occurs with: جدد, Count: 2
#   ↪ Co-occurs with: خزن, Count: 2
#   ↪ Co-occurs with: صفح, Count: 2
#   ↪ Co-occurs with: ترك, Count: 2
#   ↪ Co-occurs with: فقه, Count: 2
#   ↪ Co-occurs with: حلم, Count: 2
#   ↪ Co-occurs with: زكر, Count: 2
#   ↪ Co-occurs with: غلم, Count: 2
#   ↪ Co-occurs with: صبر, Count: 2
#   ↪ Co-occurs with: خرر, Count: 2
#   ↪ Co-occurs with: سلك, Count: 2
#   ↪ Co-occurs with: لعب, Count: 2
#   ↪ Co-occurs with: ترب, Count: 2
#   ↪ Co-occurs with: نطف, Count: 2
#   ↪ Co-occurs with: علق, Count: 2
#   ↪ Co-occurs with: قرر, Count: 2
#   ↪ Co-occurs with: طفل, Count: 2
#   ↪ Co-occurs with: كيد, Count: 2
#   ↪ Co-occurs with: هون, Count: 2
#   ↪ Co-occurs with: بهم, Count: 2
#   ↪ Co-occurs with: باس, Count: 2
#   ↪ Co-occurs with: صفف, Count: 2
#   ↪ Co-occurs with: لطف, Count: 2
#   ↪ Co-occurs with: جهد, Count: 2
#   ↪ Co-occurs with: سكن, Count: 2
#   ↪ Co-occurs with: زجج, Count: 2
#   ↪ Co-occurs with: كوكب, Count: 2
#   ↪ Co-occurs with: شرق, Count: 2
#   ↪ Co-occurs with: غرب, Count: 2
#   ↪ Co-occurs with: مسس, Count: 2
#   ↪ Co-occurs with: الف, Count: 2
#   ↪ Co-occurs with: ركم, Count: 2
#   ↪ Co-occurs with: ودق, Count: 2
#   ↪ Co-occurs with: خلل, Count: 2
#   ↪ Co-occurs with: سنو, Count: 2
#   ↪ Co-occurs with: حدق, Count: 2
#   ↪ Co-occurs with: عجز, Count: 2
#   ↪ Co-occurs with: افك, Count: 2
#   ↪ Co-occurs with: حين, Count: 2
#   ↪ Co-occurs with: بسط, Count: 2
#   ↪ Co-occurs with: انس, Count: 2
#   ↪ Co-occurs with: زول, Count: 2
#   ↪ Co-occurs with: هن, Count: 2
#   ↪ Co-occurs with: سوا, Count: 2
#   ↪ Co-occurs with: دخن, Count: 2
#   ↪ Co-occurs with: فوق, Count: 2
#   ↪ Co-occurs with: وهب, Count: 2
#   ↪ Co-occurs with: نسو, Count: 2
#   ↪ Co-occurs with: فرج, Count: 2
#   ↪ Co-occurs with: برا, Count: 2
#   ↪ Co-occurs with: طبق, Count: 2
#   ↪ Co-occurs with: بتل, Count: 2
# Root: اله
#   ↪ Co-occurs with: اله, Count: 2624
#   ↪ Co-occurs with: قول, Count: 1188
#   ↪ Co-occurs with: اللذ, Count: 1125
#   ↪ Co-occurs with: كون, Count: 974
#   ↪ Co-occurs with: علم, Count: 878
#   ↪ Co-occurs with: امن, Count: 843
#   ↪ Co-occurs with: شيا, Count: 596
#   ↪ Co-occurs with: رسل, Count: 488
#   ↪ Co-occurs with: قوم, Count: 460
#   ↪ Co-occurs with: كفر, Count: 443
#   ↪ Co-occurs with: بين, Count: 430
#   ↪ Co-occurs with: هو, Count: 417
#   ↪ Co-occurs with: اتي, Count: 411
#   ↪ Co-occurs with: ارض, Count: 380
#   ↪ Co-occurs with: ربب, Count: 368
#   ↪ Co-occurs with: سمو, Count: 319
#   ↪ Co-occurs with: كتب, Count: 300
#   ↪ Co-occurs with: هدي, Count: 296
#   ↪ Co-occurs with: كلل, Count: 286
#   ↪ Co-occurs with: غفر, Count: 282
#   ↪ Co-occurs with: نفس, Count: 272
#   ↪ Co-occurs with: وقي, Count: 258
#   ↪ Co-occurs with: رحم, Count: 254
#   ↪ Co-occurs with: نوس, Count: 252
#   ↪ Co-occurs with: حكم, Count: 252
#   ↪ Co-occurs with: عمل, Count: 249
#   ↪ Co-occurs with: يوم, Count: 239
#   ↪ Co-occurs with: جعل, Count: 237
#   ↪ Co-occurs with: نزل, Count: 236
#   ↪ Co-occurs with: حقق, Count: 236
#   ↪ Co-occurs with: اخر, Count: 229
#   ↪ Co-occurs with: قتل, Count: 225
#   ↪ Co-occurs with: امر, Count: 224
#   ↪ Co-occurs with: عذب, Count: 222
#   ↪ Co-occurs with: ظلم, Count: 222
#   ↪ Co-occurs with: عبد, Count: 221
#   ↪ Co-occurs with: سبل, Count: 220
#   ↪ Co-occurs with: بعد, Count: 209
#   ↪ Co-occurs with: ولي, Count: 209
#   ↪ Co-occurs with: شهد, Count: 205
#   ↪ Co-occurs with: راي, Count: 204
#   ↪ Co-occurs with: اخذ, Count: 204
#   ↪ Co-occurs with: ايا, Count: 199
#   ↪ Co-occurs with: ملك, Count: 189
#   ↪ Co-occurs with: خير, Count: 182
#   ↪ Co-occurs with: قلب, Count: 178
#   ↪ Co-occurs with: غير, Count: 175
#   ↪ Co-occurs with: دون, Count: 173
#   ↪ Co-occurs with: بعض, Count: 172
#   ↪ Co-occurs with: حسن, Count: 167
#   ↪ Co-occurs with: شرك, Count: 166
#   ↪ Co-occurs with: ذكر, Count: 166
#   ↪ Co-occurs with: نصر, Count: 165
#   ↪ Co-occurs with: خلق, Count: 162
#   ↪ Co-occurs with: جيا, Count: 161
#   ↪ Co-occurs with: فضل, Count: 159
#   ↪ Co-occurs with: بنو, Count: 155
#   ↪ Co-occurs with: ضلل, Count: 152
#   ↪ Co-occurs with: نفق, Count: 152
#   ↪ Co-occurs with: مثل, Count: 149
#   ↪ Co-occurs with: دعو, Count: 149
#   ↪ Co-occurs with: قبل, Count: 148
#   ↪ Co-occurs with: رود, Count: 146
#   ↪ Co-occurs with: نور, Count: 142
#   ↪ Co-occurs with: كثر, Count: 142
#   ↪ Co-occurs with: نبا, Count: 141
#   ↪ Co-occurs with: حيي, Count: 130
#   ↪ Co-occurs with: سمع, Count: 128
#   ↪ Co-occurs with: قدر, Count: 127
#   ↪ Co-occurs with: عظم, Count: 126
#   ↪ Co-occurs with: موت, Count: 125
#   ↪ Co-occurs with: طوع, Count: 125
#   ↪ Co-occurs with: حبب, Count: 123
#   ↪ Co-occurs with: دين, Count: 122
#   ↪ Co-occurs with: خرج, Count: 121
#   ↪ Co-occurs with: كذب, Count: 119
#   ↪ Co-occurs with: نعم, Count: 119
#   ↪ Co-occurs with: عزز, Count: 117
#   ↪ Co-occurs with: اذن, Count: 116
#   ↪ Co-occurs with: حرم, Count: 116
#   ↪ Co-occurs with: تبع, Count: 116
#   ↪ Co-occurs with: صدق, Count: 115
#   ↪ Co-occurs with: رزق, Count: 114
#   ↪ Co-occurs with: صلح, Count: 114
#   ↪ Co-occurs with: سلم, Count: 114
#   ↪ Co-occurs with: سوا, Count: 114
#   ↪ Co-occurs with: بغي, Count: 113
#   ↪ Co-occurs with: عدو, Count: 110
#   ↪ Co-occurs with: دنو, Count: 109
#   ↪ Co-occurs with: وكل, Count: 108
#   ↪ Co-occurs with: يدي, Count: 106
#   ↪ Co-occurs with: ولد, Count: 104
#   ↪ Co-occurs with: انتم, Count: 103
#   ↪ Co-occurs with: خلف, Count: 103
#   ↪ Co-occurs with: توب, Count: 103
#   ↪ Co-occurs with: بصر, Count: 102
#   ↪ Co-occurs with: وعد, Count: 101
#   ↪ Co-occurs with: كبر, Count: 100
#   ↪ Co-occurs with: حسب, Count: 98
#   ↪ Co-occurs with: جمع, Count: 97
#   ↪ Co-occurs with: اجر, Count: 96
#   ↪ Co-occurs with: قرب, Count: 95
#   ↪ Co-occurs with: شدد, Count: 94
#   ↪ Co-occurs with: رضو, Count: 94
#   ↪ Co-occurs with: وجد, Count: 93
#   ↪ Co-occurs with: وحد, Count: 92
#   ↪ Co-occurs with: ضرر, Count: 88
#   ↪ Co-occurs with: دخل, Count: 88
#   ↪ Co-occurs with: صلو, Count: 87
#   ↪ Co-occurs with: فعل, Count: 87
#   ↪ Co-occurs with: بشر, Count: 86
#   ↪ Co-occurs with: اهل, Count: 85
#   ↪ Co-occurs with: نهر, Count: 84
#   ↪ Co-occurs with: اخو, Count: 84
#   ↪ Co-occurs with: اول, Count: 82
#   ↪ Co-occurs with: حلل, Count: 80
#   ↪ Co-occurs with: بيت, Count: 79
#   ↪ Co-occurs with: مول, Count: 79
#   ↪ Co-occurs with: صوب, Count: 78
#   ↪ Co-occurs with: جنن, Count: 78
#   ↪ Co-occurs with: غني, Count: 76
#   ↪ Co-occurs with: سال, Count: 75
#   ↪ Co-occurs with: خوف, Count: 72
#   ↪ Co-occurs with: لقي, Count: 72
#   ↪ Co-occurs with: حمد, Count: 71
#   ↪ Co-occurs with: عرف, Count: 71
#   ↪ Co-occurs with: ابو, Count: 71
#   ↪ Co-occurs with: رجل, Count: 71
#   ↪ Co-occurs with: كلم, Count: 70
#   ↪ Co-occurs with: امم, Count: 69
#   ↪ Co-occurs with: عقب, Count: 68
#   ↪ Co-occurs with: فري, Count: 68
#   ↪ Co-occurs with: احد, Count: 67
#   ↪ Co-occurs with: زوج, Count: 67
#   ↪ Co-occurs with: نسو, Count: 67
#   ↪ Co-occurs with: يمن, Count: 66
#   ↪ Co-occurs with: خبر, Count: 66
#   ↪ Co-occurs with: ضرب, Count: 65
#   ↪ Co-occurs with: سجد, Count: 65
#   ↪ Co-occurs with: سبح, Count: 65
#   ↪ Co-occurs with: جهد, Count: 65
#   ↪ Co-occurs with: صبر, Count: 62
#   ↪ Co-occurs with: بلغ, Count: 61
#   ↪ Co-occurs with: رجع, Count: 59
#   ↪ Co-occurs with: اكل, Count: 58
#   ↪ Co-occurs with: وسع, Count: 58
#   ↪ Co-occurs with: ثلث, Count: 58
#   ↪ Co-occurs with: الم, Count: 57
#   ↪ Co-occurs with: سكن, Count: 57
#   ↪ Co-occurs with: سوي, Count: 57
#   ↪ Co-occurs with: خشي, Count: 56
#   ↪ Co-occurs with: عدد, Count: 56
#   ↪ Co-occurs with: زكو, Count: 56
#   ↪ Co-occurs with: جري, Count: 56
#   ↪ Co-occurs with: اجل, Count: 56
#   ↪ Co-occurs with: عمما, Count: 55
#   ↪ Co-occurs with: نظر, Count: 54
#   ↪ Co-occurs with: دور, Count: 54
#   ↪ Co-occurs with: جزي, Count: 54
#   ↪ Co-occurs with: شكر, Count: 54
#   ↪ Co-occurs with: قلل, Count: 53
#   ↪ Co-occurs with: ظنن, Count: 53
#   ↪ Co-occurs with: حدد, Count: 52
#   ↪ Co-occurs with: ردد, Count: 51
#   ↪ Co-occurs with: شطن, Count: 50
#   ↪ Co-occurs with: وجه, Count: 50
#   ↪ Co-occurs with: ابر, Count: 50
#   ↪ Co-occurs with: ليل, Count: 50
#   ↪ Co-occurs with: خلد, Count: 50
#   ↪ Co-occurs with: ضعف, Count: 50
#   ↪ Co-occurs with: عدل, Count: 50
#   ↪ Co-occurs with: فرق, Count: 49
#   ↪ Co-occurs with: جنح, Count: 49
#   ↪ Co-occurs with: مريم, Count: 49
#   ↪ Co-occurs with: حجج, Count: 48
#   ↪ Co-occurs with: علو, Count: 48
#   ↪ Co-occurs with: تحت, Count: 48
#   ↪ Co-occurs with: عرض, Count: 47
#   ↪ Co-occurs with: وفي, Count: 47
#   ↪ Co-occurs with: نهي, Count: 47
#   ↪ Co-occurs with: هجر, Count: 47
#   ↪ Co-occurs with: مسس, Count: 46
#   ↪ Co-occurs with: عهد, Count: 45
#   ↪ Co-occurs with: موس, Count: 45
#   ↪ Co-occurs with: كفي, Count: 45
#   ↪ Co-occurs with: قرا, Count: 45
#   ↪ Co-occurs with: فسق, Count: 44
#   ↪ Co-occurs with: كسب, Count: 44
#   ↪ Co-occurs with: طوف, Count: 44
#   ↪ Co-occurs with: مسك, Count: 44
#   ↪ Co-occurs with: صدر, Count: 44
#   ↪ Co-occurs with: مكر, Count: 44
#   ↪ Co-occurs with: زيد, Count: 43
#   ↪ Co-occurs with: عفو, Count: 43
#   ↪ Co-occurs with: فسد, Count: 42
#   ↪ Co-occurs with: ثني, Count: 42
#   ↪ Co-occurs with: قضي, Count: 42
#   ↪ Co-occurs with: بعث, Count: 42
#   ↪ Co-occurs with: صدد, Count: 42
#   ↪ Co-occurs with: وثق, Count: 41
#   ↪ Co-occurs with: قوي, Count: 41
#   ↪ Co-occurs with: يسر, Count: 41
#   ↪ Co-occurs with: كره, Count: 41
#   ↪ Co-occurs with: غيب, Count: 41
#   ↪ Co-occurs with: طعم, Count: 40
#   ↪ Co-occurs with: ظهر, Count: 40
#   ↪ Co-occurs with: اثم, Count: 40
#   ↪ Co-occurs with: اذي, Count: 40
#   ↪ Co-occurs with: لعن, Count: 39
#   ↪ Co-occurs with: وصي, Count: 39
#   ↪ Co-occurs with: ذهب, Count: 38
#   ↪ Co-occurs with: ترك, Count: 38
#   ↪ Co-occurs with: نفع, Count: 38
#   ↪ Co-occurs with: روح, Count: 38
#   ↪ Co-occurs with: عود, Count: 38
#   ↪ Co-occurs with: لما, Count: 37
#   ↪ Co-occurs with: طيب, Count: 37
#   ↪ Co-occurs with: باس, Count: 36
#   ↪ Co-occurs with: فتن, Count: 36
#   ↪ Co-occurs with: هوي, Count: 36
#   ↪ Co-occurs with: تلك, Count: 36
#   ↪ Co-occurs with: بيع, Count: 36
#   ↪ Co-occurs with: تلو, Count: 35
#   ↪ Co-occurs with: نحن, Count: 35
#   ↪ Co-occurs with: صحب, Count: 35
#   ↪ Co-occurs with: ذنب, Count: 35
#   ↪ Co-occurs with: نجو, Count: 35
#   ↪ Co-occurs with: وحي, Count: 35
#   ↪ Co-occurs with: ريب, Count: 34
#   ↪ Co-occurs with: اللت, Count: 34
#   ↪ Co-occurs with: جهنم, Count: 34
#   ↪ Co-occurs with: نذر, Count: 34
#   ↪ Co-occurs with: قرض, Count: 34
#   ↪ Co-occurs with: بدو, Count: 34
#   ↪ Co-occurs with: خفي, Count: 34
#   ↪ Co-occurs with: قسط, Count: 34
#   ↪ Co-occurs with: مسح, Count: 34
#   ↪ Co-occurs with: حزن, Count: 33
#   ↪ Co-occurs with: اسر, Count: 33
#   ↪ Co-occurs with: قدم, Count: 33
#   ↪ Co-occurs with: شهر, Count: 33
#   ↪ Co-occurs with: شري, Count: 32
#   ↪ Co-occurs with: عمر, Count: 32
#   ↪ Co-occurs with: ملل, Count: 32
#   ↪ Co-occurs with: عيس, Count: 32
#   ↪ Co-occurs with: نكح, Count: 32
#   ↪ Co-occurs with: سلط, Count: 32
#   ↪ Co-occurs with: خسر, Count: 31
#   ↪ Co-occurs with: بدل, Count: 31
#   ↪ Co-occurs with: وذر, Count: 31
#   ↪ Co-occurs with: قعد, Count: 31
#   ↪ Co-occurs with: مرض, Count: 30
#   ↪ Co-occurs with: فتح, Count: 30
#   ↪ Co-occurs with: ابد, Count: 30
#   ↪ Co-occurs with: فحش, Count: 30
#   ↪ Co-occurs with: طهر, Count: 30
#   ↪ Co-occurs with: طلق, Count: 30
#   ↪ Co-occurs with: انت, Count: 30
#   ↪ Co-occurs with: خلص, Count: 29
#   ↪ Co-occurs with: صير, Count: 29
#   ↪ Co-occurs with: صوم, Count: 29
#   ↪ Co-occurs with: نصب, Count: 29
#   ↪ Co-occurs with: ودد, Count: 28
#   ↪ Co-occurs with: متع, Count: 28
#   ↪ Co-occurs with: فلح, Count: 28
#   ↪ Co-occurs with: هلك, Count: 28
#   ↪ Co-occurs with: حفظ, Count: 28
#   ↪ Co-occurs with: بسط, Count: 28
#   ↪ Co-occurs with: حمل, Count: 28
#   ↪ Co-occurs with: موه, Count: 27
#   ↪ Co-occurs with: سرع, Count: 27
#   ↪ Co-occurs with: عسي, Count: 27
#   ↪ Co-occurs with: بلو, Count: 27
#   ↪ Co-occurs with: بطل, Count: 27
#   ↪ Co-occurs with: كتم, Count: 26
#   ↪ Co-occurs with: حدث, Count: 26
#   ↪ Co-occurs with: ثوب, Count: 26
#   ↪ Co-occurs with: برا, Count: 26
#   ↪ Co-occurs with: جدل, Count: 26
#   ↪ Co-occurs with: زين, Count: 26
#   ↪ Co-occurs with: رجو, Count: 26
#   ↪ Co-occurs with: ورث, Count: 26
#   ↪ Co-occurs with: حرج, Count: 26
#   ↪ Co-occurs with: غرر, Count: 26
#   ↪ Co-occurs with: حذر, Count: 25
#   ↪ Co-occurs with: عشر, Count: 25
#   ↪ Co-occurs with: عصي, Count: 25
#   ↪ Co-occurs with: شقق, Count: 25
#   ↪ Co-occurs with: مرا, Count: 25
#   ↪ Co-occurs with: جند, Count: 25
#   ↪ Co-occurs with: غلب, Count: 25
#   ↪ Co-occurs with: هي, Count: 24
#   ↪ Co-occurs with: سخر, Count: 24
#   ↪ Co-occurs with: درج, Count: 24
#   ↪ Co-occurs with: وعظ, Count: 24
#   ↪ Co-occurs with: جوب, Count: 24
#   ↪ Co-occurs with: افك, Count: 24
#   ↪ Co-occurs with: غضب, Count: 23
#   ↪ Co-occurs with: جهل, Count: 23
#   ↪ Co-occurs with: سرر, Count: 23
#   ↪ Co-occurs with: صرط, Count: 23
#   ↪ Co-occurs with: بحر, Count: 23
#   ↪ Co-occurs with: حلم, Count: 23
#   ↪ Co-occurs with: ربع, Count: 23
#   ↪ Co-occurs with: منن, Count: 23
#   ↪ Co-occurs with: ربو, Count: 23
#   ↪ Co-occurs with: فقر, Count: 23
#   ↪ Co-occurs with: عصم, Count: 23
#   ↪ Co-occurs with: صبح, Count: 23
#   ↪ Co-occurs with: نكر, Count: 23
#   ↪ Co-occurs with: فوز, Count: 23
#   ↪ Co-occurs with: حوط, Count: 22
#   ↪ Co-occurs with: فوق, Count: 22
#   ↪ Co-occurs with: ماذا, Count: 22
#   ↪ Co-occurs with: عقل, Count: 22
#   ↪ Co-occurs with: ثمن, Count: 22
#   ↪ Co-occurs with: نسي, Count: 22
#   ↪ Co-occurs with: برر, Count: 22
#   ↪ Co-occurs with: خون, Count: 22
#   ↪ Co-occurs with: تمم, Count: 22
#   ↪ Co-occurs with: فرض, Count: 22
#   ↪ Co-occurs with: فاو, Count: 22
#   ↪ Co-occurs with: انث, Count: 22
#   ↪ Co-occurs with: نيل, Count: 22
#   ↪ Co-occurs with: سنن, Count: 22
#   ↪ Co-occurs with: سوع, Count: 22
#   ↪ Co-occurs with: قطع, Count: 21
#   ↪ Co-occurs with: يتم, Count: 21
#   ↪ Co-occurs with: مني, Count: 21
#   ↪ Co-occurs with: ايد, Count: 21
#   ↪ Co-occurs with: عرش, Count: 21
#   ↪ Co-occurs with: شرب, Count: 20
#   ↪ Co-occurs with: هود, Count: 20
#   ↪ Co-occurs with: الف, Count: 20
#   ↪ Co-occurs with: حيث, Count: 20
#   ↪ Co-occurs with: اوي, Count: 20
#   ↪ Co-occurs with: الل, Count: 20
#   ↪ Co-occurs with: شعر, Count: 19
#   ↪ Co-occurs with: خلو, Count: 19
#   ↪ Co-occurs with: صفو, Count: 19
#   ↪ Co-occurs with: رقب, Count: 19
#   ↪ Co-occurs with: مرر, Count: 19
#   ↪ Co-occurs with: شمس, Count: 19
#   ↪ Co-occurs with: فرع, Count: 19
#   ↪ Co-occurs with: وضع, Count: 19
#   ↪ Co-occurs with: هزا, Count: 18
#   ↪ Co-occurs with: حول, Count: 18
#   ↪ Co-occurs with: وصل, Count: 18
#   ↪ Co-occurs with: عين, Count: 18
#   ↪ Co-occurs with: وري, Count: 18
#   ↪ Co-occurs with: غرب, Count: 18
#   ↪ Co-occurs with: دبب, Count: 18
#   ↪ Co-occurs with: هن, Count: 18
#   ↪ Co-occurs with: عجب, Count: 18
#   ↪ Co-occurs with: ربص, Count: 18
#   ↪ Co-occurs with: نصف, Count: 18
#   ↪ Co-occurs with: جنب, Count: 18
#   ↪ Co-occurs with: حلف, Count: 18
#   ↪ Co-occurs with: غشي, Count: 17
#   ↪ Co-occurs with: بنا, Count: 17
#   ↪ Co-occurs with: نبت, Count: 17
#   ↪ Co-occurs with: غفل, Count: 17
#   ↪ Co-occurs with: خزي, Count: 17
#   ↪ Co-occurs with: هون, Count: 17
#   ↪ Co-occurs with: حضر, Count: 17
#   ↪ Co-occurs with: سبع, Count: 17
#   ↪ Co-occurs with: حشر, Count: 17
#   ↪ Co-occurs with: فصل, Count: 17
#   ↪ Co-occurs with: شفع, Count: 17
#   ↪ Co-occurs with: ماي, Count: 17
#   ↪ Co-occurs with: طمن, Count: 17
#   ↪ Co-occurs with: نقم, Count: 17
#   ↪ Co-occurs with: حصن, Count: 17
#   ↪ Co-occurs with: دبر, Count: 17
#   ↪ Co-occurs with: جلد, Count: 17
#   ↪ Co-occurs with: قسم, Count: 17
#   ↪ Co-occurs with: حزب, Count: 17
#   ↪ Co-occurs with: عرب, Count: 17
#   ↪ Co-occurs with: حصي, Count: 17
#   ↪ Co-occurs with: كود, Count: 16
#   ↪ Co-occurs with: ذلل, Count: 16
#   ↪ Co-occurs with: راف, Count: 16
#   ↪ Co-occurs with: فيا, Count: 16
#   ↪ Co-occurs with: طير, Count: 16
#   ↪ Co-occurs with: جبل, Count: 16
#   ↪ Co-occurs with: تجر, Count: 16
#   ↪ Co-occurs with: همم, Count: 16
#   ↪ Co-occurs with: كي, Count: 16
#   ↪ Co-occurs with: فوه, Count: 16
#   ↪ Co-occurs with: بخل, Count: 16
#   ↪ Co-occurs with: كفف, Count: 16
#   ↪ Co-occurs with: ياس, Count: 16
#   ↪ Co-occurs with: سير, Count: 16
#   ↪ Co-occurs with: برك, Count: 16
#   ↪ Co-occurs with: يسف, Count: 16
#   ↪ Co-occurs with: طغو, Count: 15
#   ↪ Co-occurs with: وقد, Count: 15
#   ↪ Co-occurs with: مشي, Count: 15
#   ↪ Co-occurs with: لحم, Count: 15
#   ↪ Co-occurs with: لبس, Count: 15
#   ↪ Co-occurs with: دفع, Count: 15
#   ↪ Co-occurs with: ثبت, Count: 15
#   ↪ Co-occurs with: ابي, Count: 15
#   ↪ Co-occurs with: نوح, Count: 15
#   ↪ Co-occurs with: ندي, Count: 15
#   ↪ Co-occurs with: غيظ, Count: 15
#   ↪ Co-occurs with: ذوق, Count: 15
#   ↪ Co-occurs with: دري, Count: 15
#   ↪ Co-occurs with: فتي, Count: 15
#   ↪ Co-occurs with: حرر, Count: 15
#   ↪ Co-occurs with: جرم, Count: 15
#   ↪ Co-occurs with: بوا, Count: 14
#   ↪ Co-occurs with: يعق, Count: 14
#   ↪ Co-occurs with: سحق, Count: 14
#   ↪ Co-occurs with: صرف, Count: 14
#   ↪ Co-occurs with: بطن, Count: 14
#   ↪ Co-occurs with: قصص, Count: 14
#   ↪ Co-occurs with: عجل, Count: 14
#   ↪ Co-occurs with: شرر, Count: 14
#   ↪ Co-occurs with: رفع, Count: 14
#   ↪ Co-occurs with: عوم, Count: 14
#   ↪ Co-occurs with: نزع, Count: 14
#   ↪ Co-occurs with: تورا, Count: 14
#   ↪ Co-occurs with: حور, Count: 14
#   ↪ Co-occurs with: قرر, Count: 14
#   ↪ Co-occurs with: صنع, Count: 14
#   ↪ Co-occurs with: عجز, Count: 14
#   ↪ Co-occurs with: وصف, Count: 14
#   ↪ Co-occurs with: ولج, Count: 14
#   ↪ Co-occurs with: شجر, Count: 14
#   ↪ Co-occurs with: ويل, Count: 13
#   ↪ Co-occurs with: يهد, Count: 13
#   ↪ Co-occurs with: شرق, Count: 13
#   ↪ Co-occurs with: ضيع, Count: 13
#   ↪ Co-occurs with: حين, Count: 13
#   ↪ Co-occurs with: لبث, Count: 13
#   ↪ Co-occurs with: نشز, Count: 13
#   ↪ Co-occurs with: حرب, Count: 13
#   ↪ Co-occurs with: لسن, Count: 13
#   ↪ Co-occurs with: فرح, Count: 13
#   ↪ Co-occurs with: برز, Count: 13
#   ↪ Co-occurs with: غنم, Count: 13
#   ↪ Co-occurs with: عمي, Count: 13
#   ↪ Co-occurs with: وزر, Count: 13
#   ↪ Co-occurs with: قمر, Count: 13
#   ↪ Co-occurs with: رهب, Count: 13
#   ↪ Co-occurs with: كرم, Count: 13
#   ↪ Co-occurs with: ختم, Count: 12
#   ↪ Co-occurs with: نقض, Count: 12
#   ↪ Co-occurs with: انس, Count: 12
#   ↪ Co-occurs with: شبه, Count: 12
#   ↪ Co-occurs with: غرف, Count: 12
#   ↪ Co-occurs with: قري, Count: 12
#   ↪ Co-occurs with: صغر, Count: 12
#   ↪ Co-occurs with: جور, Count: 12
#   ↪ Co-occurs with: لوم, Count: 12
#   ↪ Co-occurs with: قهر, Count: 12
#   ↪ Co-occurs with: بدا, Count: 12
#   ↪ Co-occurs with: ضوا, Count: 11
#   ↪ Co-occurs with: فجر, Count: 11
#   ↪ Co-occurs with: فدي, Count: 11
#   ↪ Co-occurs with: جبر, Count: 11
#   ↪ Co-occurs with: بلي, Count: 11
#   ↪ Co-occurs with: سعي, Count: 11
#   ↪ Co-occurs with: قنت, Count: 11
#   ↪ Co-occurs with: سفه, Count: 11
#   ↪ Co-occurs with: سبق, Count: 11
#   ↪ Co-occurs with: راس, Count: 11
#   ↪ Co-occurs with: زيل, Count: 11
#   ↪ Co-occurs with: حبط, Count: 11
#   ↪ Co-occurs with: صور, Count: 11
#   ↪ Co-occurs with: خطا, Count: 11
#   ↪ Co-occurs with: خيل, Count: 11
#   ↪ Co-occurs with: ثوي, Count: 11
#   ↪ Co-occurs with: صيد, Count: 11
#   ↪ Co-occurs with: وطا, Count: 11
#   ↪ Co-occurs with: جهر, Count: 10
#   ↪ Co-occurs with: عوذ, Count: 10
#   ↪ Co-occurs with: عون, Count: 10
#   ↪ Co-occurs with: دمي, Count: 10
#   ↪ Co-occurs with: سفر, Count: 10
#   ↪ Co-occurs with: حصر, Count: 10
#   ↪ Co-occurs with: حرث, Count: 10
#   ↪ Co-occurs with: ظلل, Count: 10
#   ↪ Co-occurs with: غمم, Count: 10
#   ↪ Co-occurs with: كم, Count: 10
#   ↪ Co-occurs with: رضع, Count: 10
#   ↪ Co-occurs with: كلف, Count: 10
#   ↪ Co-occurs with: قدس, Count: 10
#   ↪ Co-occurs with: رشد, Count: 10
#   ↪ Co-occurs with: فضض, Count: 10
#   ↪ Co-occurs with: حظظ, Count: 10
#   ↪ Co-occurs with: طلع, Count: 10
#   ↪ Co-occurs with: خشع, Count: 10
#   ↪ Co-occurs with: سدس, Count: 10
#   ↪ Co-occurs with: خول, Count: 10
#   ↪ Co-occurs with: فقه, Count: 10
#   ↪ Co-occurs with: رغب, Count: 10
#   ↪ Co-occurs with: طبع, Count: 10
#   ↪ Co-occurs with: سرق, Count: 10
#   ↪ Co-occurs with: نجل, Count: 10
#   ↪ Co-occurs with: فطر, Count: 10
#   ↪ Co-occurs with: كشف, Count: 10
#   ↪ Co-occurs with: ثمد, Count: 10
#   ↪ Co-occurs with: رمي, Count: 10
#   ↪ Co-occurs with: نوب, Count: 10
#   ↪ Co-occurs with: شكو, Count: 10
#   ↪ Co-occurs with: اثر, Count: 10
#   ↪ Co-occurs with: زني, Count: 10
#   ↪ Co-occurs with: وطر, Count: 10
#   ↪ Co-occurs with: ندد, Count: 9
#   ↪ Co-occurs with: حجر, Count: 9
#   ↪ Co-occurs with: منع, Count: 9
#   ↪ Co-occurs with: اسم, Count: 9
#   ↪ Co-occurs with: فلك, Count: 9
#   ↪ Co-occurs with: حسر, Count: 9
#   ↪ Co-occurs with: خنزر, Count: 9
#   ↪ Co-occurs with: كمل, Count: 9
#   ↪ Co-occurs with: عكف, Count: 9
#   ↪ Co-occurs with: لبب, Count: 9
#   ↪ Co-occurs with: فيض, Count: 9
#   ↪ Co-occurs with: عزل, Count: 9
#   ↪ Co-occurs with: كسو, Count: 9
#   ↪ Co-occurs with: ركب, Count: 9
#   ↪ Co-occurs with: وبل, Count: 9
#   ↪ Co-occurs with: ذرر, Count: 9
#   ↪ Co-occurs with: خبث, Count: 9
#   ↪ Co-occurs with: زيغ, Count: 9
#   ↪ Co-occurs with: لوي, Count: 9
#   ↪ Co-occurs with: حنف, Count: 9
#   ↪ Co-occurs with: حبل, Count: 9
#   ↪ Co-occurs with: سرف, Count: 9
#   ↪ Co-occurs with: عمم, Count: 9
#   ↪ Co-occurs with: ثقل, Count: 9
#   ↪ Co-occurs with: غلل, Count: 9
#   ↪ Co-occurs with: لهو, Count: 9
#   ↪ Co-occurs with: ضيق, Count: 9
#   ↪ Co-occurs with: رجس, Count: 9
#   ↪ Co-occurs with: زعم, Count: 9
#   ↪ Co-occurs with: نشر, Count: 9
#   ↪ Co-occurs with: اسي, Count: 9
#   ↪ Co-occurs with: فسح, Count: 9
#   ↪ Co-occurs with: قسو, Count: 8
#   ↪ Co-occurs with: حرف, Count: 8
#   ↪ Co-occurs with: علن, Count: 8
#   ↪ Co-occurs with: يقن, Count: 8
#   ↪ Co-occurs with: هلل, Count: 8
#   ↪ Co-occurs with: خيط, Count: 8
#   ↪ Co-occurs with: سود, Count: 8
#   ↪ Co-occurs with: بوب, Count: 8
#   ↪ Co-occurs with: نسك, Count: 8
#   ↪ Co-occurs with: فكر, Count: 8
#   ↪ Co-occurs with: عزم, Count: 8
#   ↪ Co-occurs with: سرح, Count: 8
#   ↪ Co-occurs with: عقد, Count: 8
#   ↪ Co-occurs with: ملا, Count: 8
#   ↪ Co-occurs with: طلت, Count: 8
#   ↪ Co-occurs with: طوق, Count: 8
#   ↪ Co-occurs with: جلت, Count: 8
#   ↪ Co-occurs with: سوم, Count: 8
#   ↪ Co-occurs with: بخس, Count: 8
#   ↪ Co-occurs with: ادي, Count: 8
#   ↪ Co-occurs with: كفل, Count: 8
#   ↪ Co-occurs with: كيد, Count: 8
#   ↪ Co-occurs with: غدو, Count: 8
#   ↪ Co-occurs with: فشل, Count: 8
#   ↪ Co-occurs with: لين, Count: 8
#   ↪ Co-occurs with: غلظ, Count: 8
#   ↪ Co-occurs with: جبي, Count: 8
#   ↪ Co-occurs with: خفف, Count: 8
#   ↪ Co-occurs with: ودي, Count: 8
#   ↪ Co-occurs with: وقع, Count: 8
#   ↪ Co-occurs with: بغض, Count: 8
#   ↪ Co-occurs with: همن, Count: 8
#   ↪ Co-occurs with: صمم, Count: 8
#   ↪ Co-occurs with: جحد, Count: 8
#   ↪ Co-occurs with: وزن, Count: 8
#   ↪ Co-occurs with: ستت, Count: 8
#   ↪ Co-occurs with: نوق, Count: 8
#   ↪ Co-occurs with: سفل, Count: 8
#   ↪ Co-occurs with: نكث, Count: 8
#   ↪ Co-occurs with: زجج, Count: 8
#   ↪ Co-occurs with: زيت, Count: 8
#   ↪ Co-occurs with: خدع, Count: 7
#   ↪ Co-occurs with: سور, Count: 7
#   ↪ Co-occurs with: سقي, Count: 7
#   ↪ Co-occurs with: سحر, Count: 7
#   ↪ Co-occurs with: صفح, Count: 7
#   ↪ Co-occurs with: عنت, Count: 7
#   ↪ Co-occurs with: بعل, Count: 7
#   ↪ Co-occurs with: جوز, Count: 7
#   ↪ Co-occurs with: دود, Count: 7
#   ↪ Co-occurs with: حرق, Count: 7
#   ↪ Co-occurs with: عفف, Count: 7
#   ↪ Co-occurs with: سلف, Count: 7
#   ↪ Co-occurs with: بقي, Count: 7
#   ↪ Co-occurs with: حسس, Count: 7
#   ↪ Co-occurs with: عوج, Count: 7
#   ↪ Co-occurs with: وهن, Count: 7
#   ↪ Co-occurs with: ضجع, Count: 7
#   ↪ Co-occurs with: درك, Count: 7
#   ↪ Co-occurs with: برج, Count: 7
#   ↪ Co-occurs with: عمد, Count: 7
#   ↪ Co-occurs with: خلل, Count: 7
#   ↪ Co-occurs with: شكك, Count: 7
#   ↪ Co-occurs with: قلد, Count: 7
#   ↪ Co-occurs with: كعب, Count: 7
#   ↪ Co-occurs with: عزر, Count: 7
#   ↪ Co-occurs with: حبر, Count: 7
#   ↪ Co-occurs with: لعب, Count: 7
#   ↪ Co-occurs with: طفا, Count: 7
#   ↪ Co-occurs with: خطو, Count: 7
#   ↪ Co-occurs with: شمل, Count: 7
#   ↪ Co-occurs with: نصح, Count: 7
#   ↪ Co-occurs with: شعب, Count: 7
#   ↪ Co-occurs with: خمس, Count: 7
#   ↪ Co-occurs with: مكن, Count: 7
#   ↪ Co-occurs with: هما, Count: 7
#   ↪ Co-occurs with: نشا, Count: 7
#   ↪ Co-occurs with: لطف, Count: 7
#   ↪ Co-occurs with: زرع, Count: 7
#   ↪ Co-occurs with: مدد, Count: 6
#   ↪ Co-occurs with: ذبح, Count: 6
#   ↪ Co-occurs with: بقر, Count: 6
#   ↪ Co-occurs with: وسط, Count: 6
#   ↪ Co-occurs with: سحب, Count: 6
#   ↪ Co-occurs with: عسر, Count: 6
#   ↪ Co-occurs with: بيض, Count: 6
#   ↪ Co-occurs with: خلط, Count: 6
#   ↪ Co-occurs with: حيض, Count: 6
#   ↪ Co-occurs with: الول, Count: 6
#   ↪ Co-occurs with: قبض, Count: 6
#   ↪ Co-occurs with: نوم, Count: 6
#   ↪ Co-occurs with: عرو, Count: 6
#   ↪ Co-occurs with: بهت, Count: 6
#   ↪ Co-occurs with: حمر, Count: 6
#   ↪ Co-occurs with: سنبل, Count: 6
#   ↪ Co-occurs with: سام, Count: 6
#   ↪ Co-occurs with: داب, Count: 6
#   ↪ Co-occurs with: عبر, Count: 6
#   ↪ Co-occurs with: نفخ, Count: 6
#   ↪ Co-occurs with: شفي, Count: 6
#   ↪ Co-occurs with: دول, Count: 6
#   ↪ Co-occurs with: صعد, Count: 6
#   ↪ Co-occurs with: ميل, Count: 6
#   ↪ Co-occurs with: قرن, Count: 6
#   ↪ Co-occurs with: نكل, Count: 6
#   ↪ Co-occurs with: شحح, Count: 6
#   ↪ Co-occurs with: خوض, Count: 6
#   ↪ Co-occurs with: غلو, Count: 6
#   ↪ Co-occurs with: شنا, Count: 6
#   ↪ Co-occurs with: حمي, Count: 6
#   ↪ Co-occurs with: صدف, Count: 6
#   ↪ Co-occurs with: خزن, Count: 6
#   ↪ Co-occurs with: سبب, Count: 6
#   ↪ Co-occurs with: شرح, Count: 6
#   ↪ Co-occurs with: كيل, Count: 6
#   ↪ Co-occurs with: مدين, Count: 6
#   ↪ Co-occurs with: عذر, Count: 6
#   ↪ Co-occurs with: نفل, Count: 6
#   ↪ Co-occurs with: نقص, Count: 6
#   ↪ Co-occurs with: نفر, Count: 6
#   ↪ Co-occurs with: زبد, Count: 6
#   ↪ Co-occurs with: وهب, Count: 6
#   ↪ Co-occurs with: برهن, Count: 6
#   ↪ Co-occurs with: سرمد, Count: 6
#   ↪ Co-occurs with: مقت, Count: 6
#   ↪ Co-occurs with: صعق, Count: 5
#   ↪ Co-occurs with: خطف, Count: 5
#   ↪ Co-occurs with: ثمر, Count: 5
#   ↪ Co-occurs with: سنو, Count: 5
#   ↪ Co-occurs with: حسد, Count: 5
#   ↪ Co-occurs with: سبط, Count: 5
#   ↪ Co-occurs with: بثث, Count: 5
#   ↪ Co-occurs with: رفث, Count: 5
#   ↪ Co-occurs with: حلق, Count: 5
#   ↪ Co-occurs with: شور, Count: 5
#   ↪ Co-occurs with: جسم, Count: 5
#   ↪ Co-occurs with: ترب, Count: 5
#   ↪ Co-occurs with: ادم, Count: 5
#   ↪ Co-occurs with: طين, Count: 5
#   ↪ Co-occurs with: نقذ, Count: 5
#   ↪ Co-occurs with: قرح, Count: 5
#   ↪ Co-occurs with: محص, Count: 5
#   ↪ Co-occurs with: ميز, Count: 5
#   ↪ Co-occurs with: ربط, Count: 5
#   ↪ Co-occurs with: سفح, Count: 5
#   ↪ Co-occurs with: طول, Count: 5
#   ↪ Co-occurs with: فخر, Count: 5
#   ↪ Co-occurs with: بهم, Count: 5
#   ↪ Co-occurs with: خمص, Count: 5
#   ↪ Co-occurs with: جرح, Count: 5
#   ↪ Co-occurs with: شرع, Count: 5
#   ↪ Co-occurs with: ركع, Count: 5
#   ↪ Co-occurs with: فرط, Count: 5
#   ↪ Co-occurs with: كاننما, Count: 5
#   ↪ Co-occurs with: نجم, Count: 5
#   ↪ Co-occurs with: قرف, Count: 5
#   ↪ Co-occurs with: غور, Count: 5
#   ↪ Co-occurs with: قصد, Count: 5
#   ↪ Co-occurs with: اسس, Count: 5
#   ↪ Co-occurs with: ظما, Count: 5
#   ↪ Co-occurs with: موج, Count: 5
#   ↪ Co-occurs with: هنك, Count: 5
#   ↪ Co-occurs with: اصل, Count: 5
#   ↪ Co-occurs with: خسف, Count: 5
#   ↪ Co-occurs with: وثن, Count: 5
#   ↪ Co-occurs with: صفف, Count: 5
#   ↪ Co-occurs with: هدم, Count: 5
#   ↪ Co-occurs with: صمع, Count: 5
#   ↪ Co-occurs with: عرج, Count: 5
#   ↪ Co-occurs with: سوق, Count: 5
#   ↪ Co-occurs with: غوث, Count: 5
#   ↪ Co-occurs with: لون, Count: 5
#   ↪ Co-occurs with: محن, Count: 5
#   ↪ Co-occurs with: برق, Count: 4
#   ↪ Co-occurs with: هبط, Count: 4
#   ↪ Co-occurs with: مصر, Count: 4
#   ↪ Co-occurs with: صبا, Count: 4
#   ↪ Co-occurs with: نبذ, Count: 4
#   ↪ Co-occurs with: خصص, Count: 4
#   ↪ Co-occurs with: نسخ, Count: 4
#   ↪ Co-occurs with: صبغ, Count: 4
#   ↪ Co-occurs with: خصم, Count: 4
#   ↪ Co-occurs with: زلل, Count: 4
#   ↪ Co-occurs with: لغو, Count: 4
#   ↪ Co-occurs with: خطب, Count: 4
#   ↪ Co-occurs with: كنن, Count: 4
#   ↪ Co-occurs with: هزم, Count: 4
#   ↪ Co-occurs with: يمم, Count: 4
#   ↪ Co-occurs with: زكر, Count: 4
#   ↪ Co-occurs with: هيا, Count: 4
#   ↪ Co-occurs with: اني, Count: 4
#   ↪ Co-occurs with: صرر, Count: 4
#   ↪ Co-occurs with: نعس, Count: 4
#   ↪ Co-occurs with: هاه, Count: 4
#   ↪ Co-occurs with: خذل, Count: 4
#   ↪ Co-occurs with: سخط, Count: 4
#   ↪ Co-occurs with: صلي, Count: 4
#   ↪ Co-occurs with: وفق, Count: 4
#   ↪ Co-occurs with: عتد, Count: 4
#   ↪ Co-occurs with: رفق, Count: 4
#   ↪ Co-occurs with: ليت, Count: 4
#   ↪ Co-occurs with: حرض, Count: 4
#   ↪ Co-occurs with: رغم, Count: 4
#   ↪ Co-occurs with: سلح, Count: 4
#   ↪ Co-occurs with: حوذ, Count: 4
#   ↪ Co-occurs with: ردي, Count: 4
#   ↪ Co-occurs with: كلب, Count: 4
#   ↪ Co-occurs with: بغت, Count: 4
#   ↪ Co-occurs with: بكم, Count: 4
#   ↪ Co-occurs with: ازر, Count: 4
#   ↪ Co-occurs with: صنم, Count: 4
#   ↪ Co-occurs with: خرص, Count: 4
#   ↪ Co-occurs with: ذرا, Count: 4
#   ↪ Co-occurs with: طلب, Count: 4
#   ↪ Co-occurs with: رسو, Count: 4
#   ↪ Co-occurs with: نزغ, Count: 4
#   ↪ Co-occurs with: ثخن, Count: 4
#   ↪ Co-occurs with: كنز, Count: 4
#   ↪ Co-occurs with: غرم, Count: 4
#   ↪ Co-occurs with: عدن, Count: 4
#   ↪ Co-occurs with: قبر, Count: 4
#   ↪ Co-occurs with: هور, Count: 4
#   ↪ Co-occurs with: مدن, Count: 4
#   ↪ Co-occurs with: غرق, Count: 4
#   ↪ Co-occurs with: وعي, Count: 4
#   ↪ Co-occurs with: سيل, Count: 4
#   ↪ Co-occurs with: قرع, Count: 4
#   ↪ Co-occurs with: محو, Count: 4
#   ↪ Co-occurs with: خرر, Count: 4
#   ↪ Co-occurs with: سعر, Count: 4
#   ↪ Co-occurs with: زور, Count: 4
#   ↪ Co-occurs with: هات, Count: 4
#   ↪ Co-occurs with: خبت, Count: 4
#   ↪ Co-occurs with: غضض, Count: 4
#   ↪ Co-occurs with: فرج, Count: 4
#   ↪ Co-occurs with: كوكب, Count: 4
#   ↪ Co-occurs with: درر, Count: 4
#   ↪ Co-occurs with: شان, Count: 4
#   ↪ Co-occurs with: صرح, Count: 4
#   ↪ Co-occurs with: شطا, Count: 4
#   ↪ Co-occurs with: ويك, Count: 4
#   ↪ Co-occurs with: حجب, Count: 4
#   ↪ Co-occurs with: حيق, Count: 4
#   ↪ Co-occurs with: زلف, Count: 4
#   ↪ Co-occurs with: قشعر, Count: 4
#   ↪ Co-occurs with: عمه, Count: 3
#   ↪ Co-occurs with: عثو, Count: 3
#   ↪ Co-occurs with: طمع, Count: 3
#   ↪ Co-occurs with: غلف, Count: 3
#   ↪ Co-occurs with: حرص, Count: 3
#   ↪ Co-occurs with: خرب, Count: 3
#   ↪ Co-occurs with: بلد, Count: 3
#   ↪ Co-occurs with: شطر, Count: 3
#   ↪ Co-occurs with: جنف, Count: 3
#   ↪ Co-occurs with: وقت, Count: 3
#   ↪ Co-occurs with: خمر, Count: 3
#   ↪ Co-occurs with: امو, Count: 3
#   ↪ Co-occurs with: عضل, Count: 3
#   ↪ Co-occurs with: غوي, Count: 3
#   ↪ Co-occurs with: خوي, Count: 3
#   ↪ Co-occurs with: سنه, Count: 3
#   ↪ Co-occurs with: محق, Count: 3
#   ↪ Co-occurs with: شهو, Count: 3
#   ↪ Co-occurs with: قطر, Count: 3
#   ↪ Co-occurs with: امد, Count: 3
#   ↪ Co-occurs with: رجم, Count: 3
#   ↪ Co-occurs with: كمه, Count: 3
#   ↪ Co-occurs with: برص, Count: 3
#   ↪ Co-occurs with: دوم, Count: 3
#   ↪ Co-occurs with: درس, Count: 3
#   ↪ Co-occurs with: حفر, Count: 3
#   ↪ Co-occurs with: ثقف, Count: 3
#   ↪ Co-occurs with: بدر, Count: 3
#   ↪ Co-occurs with: كاي, Count: 3
#   ↪ Co-occurs with: رعب, Count: 3
#   ↪ Co-occurs with: فوت, Count: 3
#   ↪ Co-occurs with: غزو, Count: 3
#   ↪ Co-occurs with: فظظ, Count: 3
#   ↪ Co-occurs with: صلب, Count: 3
#   ↪ Co-occurs with: لدن, Count: 3
#   ↪ Co-occurs with: سكر, Count: 3
#   ↪ Co-occurs with: رعي, Count: 3
#   ↪ Co-occurs with: ركس, Count: 3
#   ↪ Co-occurs with: علق, Count: 3
#   ↪ Co-occurs with: كسل, Count: 3
#   ↪ Co-occurs with: نكف, Count: 3
#   ↪ Co-occurs with: نقب, Count: 3
#   ↪ Co-occurs with: ندم, Count: 3
#   ↪ Co-occurs with: انف, Count: 3
#   ↪ Co-occurs with: نهج, Count: 3
#   ↪ Co-occurs with: حير, Count: 3
#   ↪ Co-occurs with: قرطس, Count: 3
#   ↪ Co-occurs with: غمر, Count: 3
#   ↪ Co-occurs with: ابل, Count: 3
#   ↪ Co-occurs with: قصر, Count: 3
#   ↪ Co-occurs with: لحد, Count: 3
#   ↪ Co-occurs with: سيح, Count: 3
#   ↪ Co-occurs with: رصد, Count: 3
#   ↪ Co-occurs with: كسد, Count: 3
#   ↪ Co-occurs with: رحب, Count: 3
#   ↪ Co-occurs with: ضهي, Count: 3
#   ↪ Co-occurs with: نسا, Count: 3
#   ↪ Co-occurs with: لجا, Count: 3
#   ↪ Co-occurs with: ودع, Count: 3
#   ↪ Co-occurs with: زري, Count: 3
#   ↪ Co-occurs with: تبب, Count: 3
#   ↪ Co-occurs with: ورد, Count: 3
#   ↪ Co-occurs with: بضع, Count: 3
#   ↪ Co-occurs with: حلي, Count: 3
#   ↪ Co-occurs with: جزع, Count: 3
#   ↪ Co-occurs with: حيص, Count: 3
#   ↪ Co-occurs with: بور, Count: 3
#   ↪ Co-occurs with: زول, Count: 3
#   ↪ Co-occurs with: دخر, Count: 3
#   ↪ Co-occurs with: فاد, Count: 3
#   ↪ Co-occurs with: وكد, Count: 3
#   ↪ Co-occurs with: نفد, Count: 3
#   ↪ Co-occurs with: رغد, Count: 3
#   ↪ Co-occurs with: جوع, Count: 3
#   ↪ Co-occurs with: كهف, Count: 3
#   ↪ Co-occurs with: افف, Count: 3
#   ↪ Co-occurs with: عرر, Count: 3
#   ↪ Co-occurs with: نطف, Count: 3
#   ↪ Co-occurs with: طفل, Count: 3
#   ↪ Co-occurs with: عور, Count: 3
#   ↪ Co-occurs with: عشي, Count: 3
#   ↪ Co-occurs with: ثور, Count: 3
#   ↪ Co-occurs with: لقم, Count: 3
#   ↪ Co-occurs with: سطر, Count: 3
#   ↪ Co-occurs with: جلس, Count: 3
#   ↪ Co-occurs with: شفق, Count: 3
#   ↪ Co-occurs with: وجف, Count: 3
#   ↪ Co-occurs with: رعد, Count: 2
#   ↪ Co-occurs with: فرش, Count: 2
#   ↪ Co-occurs with: بقل, Count: 2
#   ↪ Co-occurs with: قثا, Count: 2
#   ↪ Co-occurs with: فوم, Count: 2
#   ↪ Co-occurs with: عدس, Count: 2
#   ↪ Co-occurs with: بصل, Count: 2
#   ↪ Co-occurs with: درا, Count: 2
#   ↪ Co-occurs with: مكل, Count: 2
#   ↪ Co-occurs with: مرو, Count: 2
#   ↪ Co-occurs with: رمض, Count: 2
#   ↪ Co-occurs with: زود, Count: 2
#   ↪ Co-occurs with: مهد, Count: 2
#   ↪ Co-occurs with: زلزل, Count: 2
#   ↪ Co-occurs with: متي, Count: 2
#   ↪ Co-occurs with: وسن, Count: 2
#   ↪ Co-occurs with: كرس, Count: 2
#   ↪ Co-occurs with: اود, Count: 2
#   ↪ Co-occurs with: فصم, Count: 2
#   ↪ Co-occurs with: صلد, Count: 2
#   ↪ Co-occurs with: طلل, Count: 2
#   ↪ Co-occurs with: لحف, Count: 2
#   ↪ Co-occurs with: خبط, Count: 2
#   ↪ Co-occurs with: رهن, Count: 2
#   ↪ Co-occurs with: اصر, Count: 2
#   ↪ Co-occurs with: رسخ, Count: 2
#   ↪ Co-occurs with: اوب, Count: 2
#   ↪ Co-occurs with: غلم, Count: 2
#   ↪ Co-occurs with: ذخر, Count: 2
#   ↪ Co-occurs with: كين, Count: 2
#   ↪ Co-occurs with: لحق, Count: 2
#   ↪ Co-occurs with: سدد, Count: 2
#   ↪ Co-occurs with: خدن, Count: 2
#   ↪ Co-occurs with: غسل, Count: 2
#   ↪ Co-occurs with: غوط, Count: 2
#   ↪ Co-occurs with: لمس, Count: 2
#   ↪ Co-occurs with: فتل, Count: 2
#   ↪ Co-occurs with: شيد, Count: 2
#   ↪ Co-occurs with: مال, Count: 2
#   ↪ Co-occurs with: مطر, Count: 2
#   ↪ Co-occurs with: بتك, Count: 2
#   ↪ Co-occurs with: طرق, Count: 2
#   ↪ Co-occurs with: خنق, Count: 2
#   ↪ Co-occurs with: وقذ, Count: 2
#   ↪ Co-occurs with: نطح, Count: 2
#   ↪ Co-occurs with: ذكي, Count: 2
#   ↪ Co-occurs with: زلم, Count: 2
#   ↪ Co-occurs with: سحت, Count: 2
#   ↪ Co-occurs with: قرد, Count: 2
#   ↪ Co-occurs with: رمح, Count: 2
#   ↪ Co-occurs with: سيب, Count: 2
#   ↪ Co-occurs with: حبس, Count: 2
#   ↪ Co-occurs with: عثر, Count: 2
#   ↪ Co-occurs with: ميد, Count: 2
#   ↪ Co-occurs with: بسل, Count: 2
#   ↪ Co-occurs with: حمم, Count: 2
#   ↪ Co-occurs with: فلق, Count: 2
#   ↪ Co-occurs with: نوي, Count: 2
#   ↪ Co-occurs with: هلم, Count: 2
#   ↪ Co-occurs with: شيع, Count: 2
#   ↪ Co-occurs with: حثث, Count: 2
#   ↪ Co-occurs with: جلي, Count: 2
#   ↪ Co-occurs with: وجل, Count: 2
#   ↪ Co-occurs with: شوك, Count: 2
#   ↪ Co-occurs with: ركم, Count: 2
#   ↪ Co-occurs with: قصو, Count: 2
#   ↪ Co-occurs with: بطر, Count: 2
#   ↪ Co-occurs with: نكص, Count: 2
#   ↪ Co-occurs with: نجس, Count: 2
#   ↪ Co-occurs with: عيل, Count: 2
#   ↪ Co-occurs with: عطو, Count: 2
#   ↪ Co-occurs with: زهق, Count: 2
#   ↪ Co-occurs with: جدر, Count: 2
#   ↪ Co-occurs with: جرف, Count: 2
#   ↪ Co-occurs with: طرد, Count: 2
#   ↪ Co-occurs with: مجد, Count: 2
#   ↪ Co-occurs with: سول, Count: 2
#   ↪ Co-occurs with: جمل, Count: 2
#   ↪ Co-occurs with: دلو, Count: 2
#   ↪ Co-occurs with: حوش, Count: 2
#   ↪ Co-occurs with: سجن, Count: 2
#   ↪ Co-occurs with: برح, Count: 2
#   ↪ Co-occurs with: زجو, Count: 2
#   ↪ Co-occurs with: جفا, Count: 2
#   ↪ Co-occurs with: مكث, Count: 2
#   ↪ Co-occurs with: جدد, Count: 2
#   ↪ Co-occurs with: صرخ, Count: 2
#   ↪ Co-occurs with: رذل, Count: 2
#   ↪ Co-occurs with: حفد, Count: 2
#   ↪ Co-occurs with: لمح, Count: 2
#   ↪ Co-occurs with: سربل, Count: 2
#   ↪ Co-occurs with: ذمم, Count: 2
#   ↪ Co-occurs with: دحر, Count: 2
#   ↪ Co-occurs with: كسف, Count: 2
#   ↪ Co-occurs with: شطط, Count: 2
#   ↪ Co-occurs with: فجو, Count: 2
#   ↪ Co-occurs with: جسد, Count: 2
#   ↪ Co-occurs with: خور, Count: 2
#   ↪ Co-occurs with: نسف, Count: 2
#   ↪ Co-occurs with: حصب, Count: 2
#   ↪ Co-occurs with: مرد, Count: 2
#   ↪ Co-occurs with: مجس, Count: 2
#   ↪ Co-occurs with: بدن, Count: 2
#   ↪ Co-occurs with: وجب, Count: 2
#   ↪ Co-occurs with: قنع, Count: 2
#   ↪ Co-occurs with: خضر, Count: 2
# ...
#   ↪ Co-occurs with: وسع, Count: 14
#   ↪ Co-occurs with: نسي, Count: 14
#   ↪ Co-occurs with: صرط, Count: 14
#   ↪ Co-occurs with: قرب, Count: 14
#   ↪ Co-occurs with: عسي, Count: 14
#   ↪ Co-occurs with: كرم, Count: 14
#   ↪ Co-occurs with: نجو, Count: 13
#   ↪ Co-occurs with: وجه, Count: 13
#   ↪ Co-occurs with: تلو, Count: 13
#   ↪ Co-occurs with: فرق, Count: 13
#   ↪ Co-occurs with: اكل, Count: 13
#   ↪ Co-occurs with: وجد, Count: 13
#   ↪ Co-occurs with: وهب, Count: 13
#   ↪ Co-occurs with: بشر, Count: 13
#   ↪ Co-occurs with: اللت, Count: 13
#   ↪ Co-occurs with: بلي, Count: 12
#   ↪ Co-occurs with: عمما, Count: 12
#   ↪ Co-occurs with: طوع, Count: 12
#   ↪ Co-occurs with: صدق, Count: 12
#   ↪ Co-occurs with: وفي, Count: 12
#   ↪ Co-occurs with: جرم, Count: 12
#   ↪ Co-occurs with: ردد, Count: 12
#   ↪ Co-occurs with: هلك, Count: 12
#   ↪ Co-occurs with: جهنم, Count: 12
#   ↪ Co-occurs with: ظنن, Count: 11
#   ↪ Co-occurs with: بدل, Count: 11
#   ↪ Co-occurs with: فتح, Count: 11
#   ↪ Co-occurs with: بعث, Count: 11
#   ↪ Co-occurs with: زكو, Count: 11
#   ↪ Co-occurs with: شرق, Count: 11
#   ↪ Co-occurs with: نفق, Count: 11
#   ↪ Co-occurs with: مول, Count: 11
#   ↪ Co-occurs with: ضعف, Count: 11
#   ↪ Co-occurs with: عوذ, Count: 11
#   ↪ Co-occurs with: علو, Count: 11
#   ↪ Co-occurs with: مدد, Count: 11
#   ↪ Co-occurs with: جزي, Count: 11
#   ↪ Co-occurs with: جوب, Count: 11
#   ↪ Co-occurs with: ذوق, Count: 11
#   ↪ Co-occurs with: قدر, Count: 11
#   ↪ Co-occurs with: فصل, Count: 11
#   ↪ Co-occurs with: هوي, Count: 11
#   ↪ Co-occurs with: ظهر, Count: 11
#   ↪ Co-occurs with: قرر, Count: 11
#   ↪ Co-occurs with: نسو, Count: 10
#   ↪ Co-occurs with: بلو, Count: 10
#   ↪ Co-occurs with: غضب, Count: 10
#   ↪ Co-occurs with: عصي, Count: 10
#   ↪ Co-occurs with: هي, Count: 10
#   ↪ Co-occurs with: متع, Count: 10
#   ↪ Co-occurs with: غفل, Count: 10
#   ↪ Co-occurs with: مري, Count: 10
#   ↪ Co-occurs with: شمس, Count: 10
#   ↪ Co-occurs with: غرب, Count: 10
#   ↪ Co-occurs with: مسس, Count: 10
#   ↪ Co-occurs with: نهي, Count: 10
#   ↪ Co-occurs with: زوج, Count: 10
#   ↪ Co-occurs with: ذنب, Count: 10
#   ↪ Co-occurs with: ثلث, Count: 10
#   ↪ Co-occurs with: انتم, Count: 10
#   ↪ Co-occurs with: عقب, Count: 10
#   ↪ Co-occurs with: لعن, Count: 10
#   ↪ Co-occurs with: عجل, Count: 10
#   ↪ Co-occurs with: فري, Count: 10
#   ↪ Co-occurs with: رجو, Count: 10
#   ↪ Co-occurs with: فسد, Count: 9
#   ↪ Co-occurs with: نحن, Count: 9
#   ↪ Co-occurs with: سكن, Count: 9
#   ↪ Co-occurs with: حزن, Count: 9
#   ↪ Co-occurs with: حدث, Count: 9
#   ↪ Co-occurs with: قلل, Count: 9
#   ↪ Co-occurs with: جبل, Count: 9
#   ↪ Co-occurs with: ملل, Count: 9
#   ↪ Co-occurs with: ريب, Count: 9
#   ↪ Co-occurs with: دور, Count: 9
#   ↪ Co-occurs with: مريم, Count: 9
#   ↪ Co-occurs with: طيب, Count: 9
#   ↪ Co-occurs with: اسر, Count: 9
#   ↪ Co-occurs with: عدد, Count: 9
#   ↪ Co-occurs with: برك, Count: 9
#   ↪ Co-occurs with: نصح, Count: 9
#   ↪ Co-occurs with: نوب, Count: 9
#   ↪ Co-occurs with: ضرب, Count: 8
#   ↪ Co-occurs with: سوم, Count: 8
#   ↪ Co-occurs with: باس, Count: 8
#   ↪ Co-occurs with: صير, Count: 8
#   ↪ Co-occurs with: رفع, Count: 8
#   ↪ Co-occurs with: الم, Count: 8
#   ↪ Co-occurs with: بقي, Count: 8
#   ↪ Co-occurs with: قدم, Count: 8
#   ↪ Co-occurs with: حلل, Count: 8
#   ↪ Co-occurs with: لما, Count: 8
#   ↪ Co-occurs with: حبب, Count: 8
#   ↪ Co-occurs with: نفع, Count: 8
#   ↪ Co-occurs with: زين, Count: 8
#   ↪ Co-occurs with: خسر, Count: 8
#   ↪ Co-occurs with: صدر, Count: 8
#   ↪ Co-occurs with: صرف, Count: 8
#   ↪ Co-occurs with: ملا, Count: 8
#   ↪ Co-occurs with: خرر, Count: 8
#   ↪ Co-occurs with: سبق, Count: 8
#   ↪ Co-occurs with: غيب, Count: 8
#   ↪ Co-occurs with: عطو, Count: 8
#   ↪ Co-occurs with: روح, Count: 8
#   ↪ Co-occurs with: فلح, Count: 7
#   ↪ Co-occurs with: فسق, Count: 7
#   ↪ Co-occurs with: طعم, Count: 7
#   ↪ Co-occurs with: بلد, Count: 7
#   ↪ Co-occurs with: دين, Count: 7
#   ↪ Co-occurs with: عدل, Count: 7
#   ↪ Co-occurs with: لدن, Count: 7
#   ↪ Co-occurs with: زكر, Count: 7
#   ↪ Co-occurs with: برا, Count: 7
#   ↪ Co-occurs with: صوب, Count: 7
#   ↪ Co-occurs with: جنب, Count: 7
#   ↪ Co-occurs with: شجر, Count: 7
#   ↪ Co-occurs with: قري, Count: 7
#   ↪ Co-occurs with: بسط, Count: 7
#   ↪ Co-occurs with: عين, Count: 7
#   ↪ Co-occurs with: حشر, Count: 7
#   ↪ Co-occurs with: وذر, Count: 7
#   ↪ Co-occurs with: سلط, Count: 7
#   ↪ Co-occurs with: ورث, Count: 7
#   ↪ Co-occurs with: سخر, Count: 7
#   ↪ Co-occurs with: راس, Count: 7
#   ↪ Co-occurs with: سوع, Count: 7
#   ↪ Co-occurs with: كره, Count: 7
#   ↪ Co-occurs with: غوي, Count: 7
#   ↪ Co-occurs with: سجن, Count: 7
#   ↪ Co-occurs with: يقن, Count: 7
#   ↪ Co-occurs with: وصف, Count: 7
#   ↪ Co-occurs with: ماذا, Count: 6
#   ↪ Co-occurs with: بكر, Count: 6
#   ↪ Co-occurs with: عون, Count: 6
#   ↪ Co-occurs with: ثمر, Count: 6
#   ↪ Co-occurs with: انث, Count: 6
#   ↪ Co-occurs with: جنح, Count: 6
#   ↪ Co-occurs with: شعر, Count: 6
#   ↪ Co-occurs with: هرن, Count: 6
#   ↪ Co-occurs with: طير, Count: 6
#   ↪ Co-occurs with: صور, Count: 6
#   ↪ Co-occurs with: علن, Count: 6
#   ↪ Co-occurs with: مرا, Count: 6
#   ↪ Co-occurs with: اثم, Count: 6
#   ↪ Co-occurs with: بطن, Count: 6
#   ↪ Co-occurs with: وضع, Count: 6
#   ↪ Co-occurs with: خزي, Count: 6
#   ↪ Co-occurs with: ثوب, Count: 6
#   ↪ Co-occurs with: الل, Count: 6
#   ↪ Co-occurs with: دوم, Count: 6
#   ↪ Co-occurs with: غلل, Count: 6
#   ↪ Co-occurs with: طغو, Count: 6
#   ↪ Co-occurs with: قطع, Count: 6
#   ↪ Co-occurs with: شفع, Count: 6
#   ↪ Co-occurs with: قمر, Count: 6
#   ↪ Co-occurs with: تلك, Count: 6
#   ↪ Co-occurs with: درج, Count: 6
#   ↪ Co-occurs with: عمي, Count: 6
#   ↪ Co-occurs with: غرر, Count: 6
#   ↪ Co-occurs with: غني, Count: 6
#   ↪ Co-occurs with: بدو, Count: 6
#   ↪ Co-occurs with: نوح, Count: 6
#   ↪ Co-occurs with: عتو, Count: 6
#   ↪ Co-occurs with: وقت, Count: 6
#   ↪ Co-occurs with: دكك, Count: 6
#   ↪ Co-occurs with: ثقل, Count: 6
#   ↪ Co-occurs with: جبي, Count: 6
#   ↪ Co-occurs with: صبح, Count: 6
#   ↪ Co-occurs with: حوط, Count: 6
#   ↪ Co-occurs with: قسم, Count: 6
#   ↪ Co-occurs with: خزن, Count: 6
#   ↪ Co-occurs with: بنا, Count: 6
#   ↪ Co-occurs with: حول, Count: 6
#   ↪ Co-occurs with: سوق, Count: 6
#   ↪ Co-occurs with: ادم, Count: 5
#   ↪ Co-occurs with: ذلل, Count: 5
#   ↪ Co-occurs with: شبه, Count: 5
#   ↪ Co-occurs with: خلو, Count: 5
#   ↪ Co-occurs with: ودد, Count: 5
#   ↪ Co-occurs with: عهد, Count: 5
#   ↪ Co-occurs with: نسك, Count: 5
#   ↪ Co-occurs with: سحق, Count: 5
#   ↪ Co-occurs with: يعق, Count: 5
#   ↪ Co-occurs with: خلص, Count: 5
#   ↪ Co-occurs with: عرف, Count: 5
#   ↪ Co-occurs with: ربو, Count: 5
#   ↪ Co-occurs with: وعظ, Count: 5
#   ↪ Co-occurs with: صغر, Count: 5
#   ↪ Co-occurs with: حضر, Count: 5
#   ↪ Co-occurs with: خطا, Count: 5
#   ↪ Co-occurs with: غلم, Count: 5
#   ↪ Co-occurs with: عشي, Count: 5
#   ↪ Co-occurs with: تورا, Count: 5
#   ↪ Co-occurs with: كفي, Count: 5
#   ↪ Co-occurs with: سرع, Count: 5
#   ↪ Co-occurs with: سرف, Count: 5
#   ↪ Co-occurs with: برر, Count: 5
#   ↪ Co-occurs with: هجر, Count: 5
#   ↪ Co-occurs with: ثمن, Count: 5
#   ↪ Co-occurs with: ابد, Count: 5
#   ↪ Co-occurs with: حفظ, Count: 5
#   ↪ Co-occurs with: مسح, Count: 5
#   ↪ Co-occurs with: اوي, Count: 5
#   ↪ Co-occurs with: دبر, Count: 5
#   ↪ Co-occurs with: جهل, Count: 5
#   ↪ Co-occurs with: افل, Count: 5
#   ↪ Co-occurs with: فحش, Count: 5
#   ↪ Co-occurs with: خفي, Count: 5
#   ↪ Co-occurs with: عجب, Count: 5
#   ↪ Co-occurs with: كشف, Count: 5
#   ↪ Co-occurs with: شكك, Count: 5
#   ↪ Co-occurs with: قوي, Count: 5
#   ↪ Co-occurs with: خبر, Count: 5
#   ↪ Co-occurs with: فتي, Count: 5
#   ↪ Co-occurs with: لبث, Count: 5
#   ↪ Co-occurs with: سنو, Count: 5
#   ↪ Co-occurs with: ودي, Count: 5
#   ↪ Co-occurs with: بحر, Count: 5
#   ↪ Co-occurs with: رشد, Count: 5
#   ↪ Co-occurs with: شفق, Count: 5
#   ↪ Co-occurs with: شقي, Count: 5
#   ↪ Co-occurs with: يمن, Count: 5
#   ↪ Co-occurs with: جحم, Count: 5
#   ↪ Co-occurs with: قدس, Count: 4
#   ↪ Co-occurs with: نبت, Count: 4
#   ↪ Co-occurs with: سرر, Count: 4
#   ↪ Co-occurs with: اسم, Count: 4
#   ↪ Co-occurs with: عيس, Count: 4
#   ↪ Co-occurs with: عفو, Count: 4
#   ↪ Co-occurs with: ثبت, Count: 4
#   ↪ Co-occurs with: ربع, Count: 4
#   ↪ Co-occurs with: سعي, Count: 4
#   ↪ Co-occurs with: اذي, Count: 4
#   ↪ Co-occurs with: بيع, Count: 4
#   ↪ Co-occurs with: كتم, Count: 4
#   ↪ Co-occurs with: عمر, Count: 4
#   ↪ Co-occurs with: رجم, Count: 4
#   ↪ Co-occurs with: عقر, Count: 4
#   ↪ Co-occurs with: قنت, Count: 4
#   ↪ Co-occurs with: ركع, Count: 4
#   ↪ Co-occurs with: الف, Count: 4
#   ↪ Co-occurs with: رقب, Count: 4
#   ↪ Co-occurs with: برهن, Count: 4
#   ↪ Co-occurs with: شهر, Count: 4
#   ↪ Co-occurs with: ذهب, Count: 4
#   ↪ Co-occurs with: اسي, Count: 4
#   ↪ Co-occurs with: وقف, Count: 4
#   ↪ Co-occurs with: دبب, Count: 4
#   ↪ Co-occurs with: غدو, Count: 4
#   ↪ Co-occurs with: ستت, Count: 4
#   ↪ Co-occurs with: وقع, Count: 4
#   ↪ Co-occurs with: ثمد, Count: 4
#   ↪ Co-occurs with: جلي, Count: 4
#   ↪ Co-occurs with: صعق, Count: 4
#   ↪ Co-occurs with: سبع, Count: 4
#   ↪ Co-occurs with: سحر, Count: 4
#   ↪ Co-occurs with: كيد, Count: 4
#   ↪ Co-occurs with: سقي, Count: 4
#   ↪ Co-occurs with: فطر, Count: 4
#   ↪ Co-occurs with: راف, Count: 4
#   ↪ Co-occurs with: شرب, Count: 4
#   ↪ Co-occurs with: يسر, Count: 4
#   ↪ Co-occurs with: كنن, Count: 4
#   ↪ Co-occurs with: موه, Count: 4
#   ↪ Co-occurs with: حصي, Count: 4
#   ↪ Co-occurs with: كنز, Count: 4
#   ↪ Co-occurs with: نفد, Count: 4
#   ↪ Co-occurs with: صرح, Count: 4
#   ↪ Co-occurs with: بوا, Count: 3
#   ↪ Co-occurs with: هود, Count: 3
#   ↪ Co-occurs with: بقر, Count: 3
#   ↪ Co-occurs with: لون, Count: 3
#   ↪ Co-occurs with: عقل, Count: 3
#   ↪ Co-occurs with: قعد, Count: 3
#   ↪ Co-occurs with: شطر, Count: 3
#   ↪ Co-occurs with: قصص, Count: 3
#   ↪ Co-occurs with: حرر, Count: 3
#   ↪ Co-occurs with: خفف, Count: 3
#   ↪ Co-occurs with: فيض, Count: 3
#   ↪ Co-occurs with: فرغ, Count: 3
#   ↪ Co-occurs with: بخس, Count: 3
#   ↪ Co-occurs with: سفه, Count: 3
#   ↪ Co-occurs with: كلف, Count: 3
#   ↪ Co-occurs with: اصر, Count: 3
#   ↪ Co-occurs with: طوق, Count: 3
#   ↪ Co-occurs with: زيغ, Count: 3
#   ↪ Co-occurs with: لبب, Count: 3
#   ↪ Co-occurs with: هيا, Count: 3
#   ↪ Co-occurs with: نفخ, Count: 3
#   ↪ Co-occurs with: وهن, Count: 3
#   ↪ Co-occurs with: فكر, Count: 3
#   ↪ Co-occurs with: حبر, Count: 3
#   ↪ Co-occurs with: نجل, Count: 3
#   ↪ Co-occurs with: طمع, Count: 3
#   ↪ Co-occurs with: فرط, Count: 3
#   ↪ Co-occurs with: طرد, Count: 3
#   ↪ Co-occurs with: بزغ, Count: 3
#   ↪ Co-occurs with: زخرف, Count: 3
#   ↪ Co-occurs with: عشر, Count: 3
#   ↪ Co-occurs with: ثوي, Count: 3
#   ↪ Co-occurs with: نشا, Count: 3
#   ↪ Co-occurs with: رجس, Count: 3
#   ↪ Co-occurs with: صدف, Count: 3
#   ↪ Co-occurs with: وري, Count: 3
#   ↪ Co-occurs with: ورق, Count: 3
#   ↪ Co-occurs with: نزع, Count: 3
#   ↪ Co-occurs with: غشي, Count: 3
#   ↪ Co-occurs with: ضرع, Count: 3
#   ↪ Co-occurs with: جدل, Count: 3
#   ↪ Co-occurs with: نقم, Count: 3
#   ↪ Co-occurs with: رجز, Count: 3
#   ↪ Co-occurs with: اسف, Count: 3
#   ↪ Co-occurs with: رهب, Count: 3
#   ↪ Co-occurs with: غوث, Count: 3
#   ↪ Co-occurs with: طمس, Count: 3
#   ↪ Co-occurs with: لزم, Count: 3
#   ↪ Co-occurs with: نصو, Count: 3
#   ↪ Co-occurs with: وصل, Count: 3
#   ↪ Co-occurs with: بوب, Count: 3
#   ↪ Co-occurs with: بول, Count: 3
#   ↪ Co-occurs with: لطف, Count: 3
#   ↪ Co-occurs with: جدد, Count: 3
#   ↪ Co-occurs with: حين, Count: 3
#   ↪ Co-occurs with: سلك, Count: 3
#   ↪ Co-occurs with: جهد, Count: 3
#   ↪ Co-occurs with: قرن, Count: 3
#   ↪ Co-occurs with: حذر, Count: 3
#   ↪ Co-occurs with: عزل, Count: 3
#   ↪ Co-occurs with: مدن, Count: 3
#   ↪ Co-occurs with: غلب, Count: 3
#   ↪ Co-occurs with: كلب, Count: 3
#   ↪ Co-occurs with: صفف, Count: 3
#   ↪ Co-occurs with: ويل, Count: 3
#   ↪ Co-occurs with: نكر, Count: 3
#   ↪ Co-occurs with: هون, Count: 3
#   ↪ Co-occurs with: طرف, Count: 3
#   ↪ Co-occurs with: خصم, Count: 3
#   ↪ Co-occurs with: ثني, Count: 3
#   ↪ Co-occurs with: عدن, Count: 3
#   ↪ Co-occurs with: طلق, Count: 3
#   ↪ Co-occurs with: دري, Count: 3
#   ↪ Co-occurs with: طوف, Count: 3
#   ↪ Co-occurs with: رغب, Count: 3
#   ↪ Co-occurs with: دمي, Count: 2
#   ↪ Co-occurs with: ذبح, Count: 2
#   ↪ Co-occurs with: فرض, Count: 2
#   ↪ Co-occurs with: نيل, Count: 2
#   ↪ Co-occurs with: سبط, Count: 2
#   ↪ Co-occurs with: حيث, Count: 2
#   ↪ Co-occurs with: ادي, Count: 2
#   ↪ Co-occurs with: ترك, Count: 2
#   ↪ Co-occurs with: جند, Count: 2
#   ↪ Co-occurs with: بهت, Count: 2
#   ↪ Co-occurs with: سلف, Count: 2
#   ↪ Co-occurs with: ابي, Count: 2
#   ↪ Co-occurs with: سام, Count: 2
#   ↪ Co-occurs with: قسط, Count: 2
#   ↪ Co-occurs with: سفر, Count: 2
#   ↪ Co-occurs with: طهر, Count: 2
#   ↪ Co-occurs with: حرب, Count: 2
#   ↪ Co-occurs with: هنك, Count: 2
#   ↪ Co-occurs with: رمز, Count: 2
#   ↪ Co-occurs with: طين, Count: 2
#   ↪ Co-occurs with: خمس, Count: 2
#   ↪ Co-occurs with: كاي, Count: 2
#   ↪ Co-occurs with: كين, Count: 2
#   ↪ Co-occurs with: بطل, Count: 2
#   ↪ Co-occurs with: شري, Count: 2
#   ↪ Co-occurs with: خول, Count: 2
#   ↪ Co-occurs with: رضع, Count: 2
#   ↪ Co-occurs with: صلب, Count: 2
#   ↪ Co-occurs with: كفف, Count: 2
#   ↪ Co-occurs with: صدد, Count: 2
#   ↪ Co-occurs with: صنع, Count: 2
#   ↪ Co-occurs with: بغض, Count: 2
#   ↪ Co-occurs with: ميد, Count: 2
#   ↪ Co-occurs with: ليت, Count: 2
#   ↪ Co-occurs with: سبب, Count: 2
#   ↪ Co-occurs with: وصي, Count: 2
#   ↪ Co-occurs with: طفق, Count: 2
#   ↪ Co-occurs with: خصف, Count: 2
#   ↪ Co-occurs with: درك, Count: 2
#   ↪ Co-occurs with: طلب, Count: 2
#   ↪ Co-occurs with: حثث, Count: 2
#   ↪ Co-occurs with: نجم, Count: 2
#   ↪ Co-occurs with: نوق, Count: 2
#   ↪ Co-occurs with: مدين, Count: 2
#   ↪ Co-occurs with: وزن, Count: 2
#   ↪ Co-occurs with: دمر, Count: 2
#   ↪ Co-occurs with: لوح, Count: 2
#   ↪ Co-occurs with: كود, Count: 2
#   ↪ Co-occurs with: رسو, Count: 2
#   ↪ Co-occurs with: بغت, Count: 2
#   ↪ Co-occurs with: حفي, Count: 2
#   ↪ Co-occurs with: مرر, Count: 2
#   ↪ Co-occurs with: اصل, Count: 2
#   ↪ Co-occurs with: وجل, Count: 2
#   ↪ Co-occurs with: عنق, Count: 2
#   ↪ Co-occurs with: شفي, Count: 2
#   ↪ Co-occurs with: عزب, Count: 2
#   ↪ Co-occurs with: حزب, Count: 2
#   ↪ Co-occurs with: خبت, Count: 2
#   ↪ Co-occurs with: لوط, Count: 2
#   ↪ Co-occurs with: سرو, Count: 2
#   ↪ Co-occurs with: همم, Count: 2
#   ↪ Co-occurs with: قهر, Count: 2
#   ↪ Co-occurs with: خمر, Count: 2
#   ↪ Co-occurs with: بضع, Count: 2
#   ↪ Co-occurs with: نزغ, Count: 2
#   ↪ Co-occurs with: لحق, Count: 2
#   ↪ Co-occurs with: زرع, Count: 2
#   ↪ Co-occurs with: فاد, Count: 2
#   ↪ Co-occurs with: سنن, Count: 2
#   ↪ Co-occurs with: سطر, Count: 2
#   ↪ Co-occurs with: كم, Count: 2
#   ↪ Co-occurs with: حظر, Count: 2
#   ↪ Co-occurs with: اوب, Count: 2
#   ↪ Co-occurs with: صفو, Count: 2
#   ↪ Co-occurs with: فقه, Count: 2
#   ↪ Co-occurs with: وقر, Count: 2
#   ↪ Co-occurs with: دود, Count: 2
#   ↪ Co-occurs with: وسل, Count: 2
#   ↪ Co-occurs with: رقي, Count: 2
#   ↪ Co-occurs with: كهف, Count: 2
#   ↪ Co-occurs with: ربط, Count: 2
#   ↪ Co-occurs with: شطط, Count: 2
#   ↪ Co-occurs with: رفق, Count: 2
#   ↪ Co-occurs with: صعد, Count: 2
#   ↪ Co-occurs with: زعم, Count: 2
#   ↪ Co-occurs with: جدر, Count: 2
#   ↪ Co-occurs with: يتم, Count: 2
#   ↪ Co-occurs with: شعل, Count: 2
#   ↪ Co-occurs with: شيب, Count: 2
#   ↪ Co-occurs with: طوي, Count: 2
#   ↪ Co-occurs with: شرح, Count: 2
#   ↪ Co-occurs with: طول, Count: 2
#   ↪ Co-occurs with: نسف, Count: 2
#   ↪ Co-occurs with: طلع, Count: 2
#   ↪ Co-occurs with: اني, Count: 2
#   ↪ Co-occurs with: ايب, Count: 2
#   ↪ Co-occurs with: فرد, Count: 2
#   ↪ Co-occurs with: صبب, Count: 2
#   ↪ Co-occurs with: حمم, Count: 2
#   ↪ Co-occurs with: ظلل, Count: 2
#   ↪ Co-occurs with: وزع, Count: 2
#   ↪ Co-occurs with: لجج, Count: 2
#   ↪ Co-occurs with: مرد, Count: 2
#   ↪ Co-occurs with: نكس, Count: 2
#   ↪ Co-occurs with: سبا, Count: 2
#   ↪ Co-occurs with: شمل, Count: 2
#   ↪ Co-occurs with: مزق, Count: 2
#   ↪ Co-occurs with: ولج, Count: 2
#   ↪ Co-occurs with: نعج, Count: 2
#   ↪ Co-occurs with: حجب, Count: 2
#   ↪ Co-occurs with: ندد, Count: 2
#   ↪ Co-occurs with: غرف, Count: 2
#   ↪ Co-occurs with: جلد, Count: 2
#   ↪ Co-occurs with: زمر, Count: 2
#   ↪ Co-occurs with: حفف, Count: 2
#   ↪ Co-occurs with: عيش, Count: 2
#   ↪ Co-occurs with: فوز, Count: 2
#   ↪ Co-occurs with: فكه, Count: 2
#   ↪ Co-occurs with: جلل, Count: 2
#   ↪ Co-occurs with: حدد, Count: 2
#   ↪ Co-occurs with: بتل, Count: 2
#   ↪ Co-occurs with: مرض, Count: 2
#   ↪ Co-occurs with: قرض, Count: 2
#   ↪ Co-occurs with: كدح, Count: 2

# %%
# Config Root

specific_root = "صلح"  # Change this value as needed

# %%
# Specific Root co-occurrence + Total Frequency Count

import json

# --- Load Filtered Co-Occurrence Data ---
cooccurrence_file = "Data/filtered_cooccurrence_data.json"
with open(cooccurrence_file, "r", encoding="utf-8") as f:
    filtered_cooccurrence_counts = json.load(f)

# --- Load Unified Quran Data to Count Root Occurrences ---
quran_data_file = "Data/filtered_unified_quran_data.json"  # Adjust if needed
with open(quran_data_file, "r", encoding="utf-8") as f:
    quran_verses = json.load(f)

# --- Count Total Occurrences and Unique Verses ---
total_occurrences = 0
verse_occurrences = 0
for verse in quran_verses:
    roots = verse.get("arabic_roots", [])  # or use "filtered_roots"
    count_in_verse = roots.count(specific_root)
    if count_in_verse > 0:
        total_occurrences += count_in_verse
        verse_occurrences += 1

print(f"\n📌 Root '{specific_root}' appears {total_occurrences} times in total.")
print(f"📌 It appears in {verse_occurrences} unique verses.")

# --- Extract Co-occurrence Data and Save ---
if specific_root in filtered_cooccurrence_counts:
    print(f"\n🔹 Co-Occurrence Data for Stem: {specific_root}")

    sorted_cooccurrences = sorted(
        filtered_cooccurrence_counts[specific_root].items(),
        key=lambda x: x[1],
        reverse=True
    )

    specific_root_data = {
        "stem": specific_root,
        "total_occurrences": total_occurrences,
        "verse_occurrences": verse_occurrences,
        "cooccurrences": [
            {"co-stem": co_stem, "count": count} for co_stem, count in sorted_cooccurrences
        ]
    }

    specific_root_file = f"Output/{specific_root}_cooccurrence.json"
    with open(specific_root_file, "w", encoding="utf-8") as f:
        json.dump(specific_root_data, f, ensure_ascii=False, indent=4)

    print(f"✅ Co-occurrence data saved to: {specific_root_file}")

    # --- Preview ---
    print("\n🔹 Top Co-Occurrences:")
    for entry in specific_root_data["cooccurrences"]:
        print(f"  ↪ Co-stem: {entry['co-stem']}, Count: {entry['count']}")
else:
    print(f"⚠ No co-occurrence data found for stem: {specific_root}")
# Out:
# 📌 Root 'صلح' appears 180 times in total.
# 📌 It appears in 170 unique verses.
#
# 🔹 Co-Occurrence Data for Stem: صلح
# ✅ Co-occurrence data saved to: Output/صلح_cooccurrence.json
#
# 🔹 Top Co-Occurrences:
#   ↪ Co-stem: عمل, Count: 118
#   ↪ Co-stem: اله, Count: 114
#   ↪ Co-stem: امن, Count: 102
#   ↪ Co-stem: اللذ, Count: 95
#   ↪ Co-stem: ربب, Count: 46
#   ↪ Co-stem: كون, Count: 43
#   ↪ Co-stem: قول, Count: 38
#   ↪ Co-stem: حسن, Count: 27
#   ↪ Co-stem: جنن, Count: 26
#   ↪ Co-stem: دخل, Count: 26
#   ↪ Co-stem: اجر, Count: 25
#   ↪ Co-stem: توب, Count: 24
#   ↪ Co-stem: بين, Count: 24
#   ↪ Co-stem: رحم, Count: 24
#   ↪ Co-stem: صلح, Count: 22
#   ↪ Co-stem: غفر, Count: 21
#   ↪ Co-stem: قوم, Count: 19
#   ↪ Co-stem: هو, Count: 19
#   ↪ Co-stem: سوا, Count: 19
#   ↪ Co-stem: اتي, Count: 18
#   ↪ Co-stem: كفر, Count: 18
#   ↪ Co-stem: رسل, Count: 17
#   ↪ Co-stem: وقي, Count: 16
#   ↪ Co-stem: عبد, Count: 16
#   ↪ Co-stem: تحت, Count: 15
#   ↪ Co-stem: اخر, Count: 15
#   ↪ Co-stem: نفس, Count: 15
#   ↪ Co-stem: خير, Count: 15
#   ↪ Co-stem: ظلم, Count: 15
#   ↪ Co-stem: بعد, Count: 15
#   ↪ Co-stem: ارض, Count: 14
#   ↪ Co-stem: خوف, Count: 14
#   ↪ Co-stem: نعم, Count: 14
#   ↪ Co-stem: جري, Count: 13
#   ↪ Co-stem: نهر, Count: 13
#   ↪ Co-stem: رود, Count: 13
#   ↪ Co-stem: رزق, Count: 12
#   ↪ Co-stem: علم, Count: 12
#   ↪ Co-stem: خلد, Count: 11
#   ↪ Co-stem: فسد, Count: 10
#   ↪ Co-stem: يوم, Count: 10
#   ↪ Co-stem: اخو, Count: 10
#   ↪ Co-stem: جعل, Count: 10
#   ↪ Co-stem: حكم, Count: 9
#   ↪ Co-stem: غير, Count: 9
#   ↪ Co-stem: جزي, Count: 9
#   ↪ Co-stem: اللت, Count: 9
#   ↪ Co-stem: بشر, Count: 8
#   ↪ Co-stem: شيا, Count: 8
#   ↪ Co-stem: مثل, Count: 8
#   ↪ Co-stem: حيي, Count: 8
#   ↪ Co-stem: امر, Count: 8
#   ↪ Co-stem: فضل, Count: 8
#   ↪ Co-stem: بغي, Count: 8
#   ↪ Co-stem: كبر, Count: 8
#   ↪ Co-stem: وعد, Count: 8
#   ↪ Co-stem: ذكر, Count: 8
#   ↪ Co-stem: شدد, Count: 8
#   ↪ Co-stem: دنو, Count: 7
#   ↪ Co-stem: عزز, Count: 7
#   ↪ Co-stem: حقق, Count: 7
#   ↪ Co-stem: حبب, Count: 7
#   ↪ Co-stem: طوع, Count: 7
#   ↪ Co-stem: رضو, Count: 7
#   ↪ Co-stem: عذب, Count: 7
#   ↪ Co-stem: جيا, Count: 7
#   ↪ Co-stem: كتب, Count: 7
#   ↪ Co-stem: قتل, Count: 7
#   ↪ Co-stem: ولد, Count: 7
#   ↪ Co-stem: كلل, Count: 6
#   ↪ Co-stem: زوج, Count: 6
#   ↪ Co-stem: سال, Count: 6
#   ↪ Co-stem: صدق, Count: 6
#   ↪ Co-stem: عظم, Count: 6
#   ↪ Co-stem: سلم, Count: 6
#   ↪ Co-stem: حمل, Count: 6
#   ↪ Co-stem: شكر, Count: 6
#   ↪ Co-stem: هدي, Count: 6
#   ↪ Co-stem: نصر, Count: 5
#   ↪ Co-stem: حزن, Count: 5
#   ↪ Co-stem: وصي, Count: 5
#   ↪ Co-stem: عرض, Count: 5
#   ↪ Co-stem: ملك, Count: 5
#   ↪ Co-stem: اهل, Count: 5
#   ↪ Co-stem: ابد, Count: 5
#   ↪ Co-stem: مرا, Count: 5
#   ↪ Co-stem: جنح, Count: 5
#   ↪ Co-stem: ولي, Count: 5
#   ↪ Co-stem: ايا, Count: 5
#   ↪ Co-stem: دعو, Count: 5
#   ↪ Co-stem: قرب, Count: 5
#   ↪ Co-stem: خلف, Count: 5
#   ↪ Co-stem: نزل, Count: 5
#   ↪ Co-stem: قسط, Count: 5
#   ↪ Co-stem: ابو, Count: 5
#   ↪ Co-stem: ذرر, Count: 5
#   ↪ Co-stem: بلغ, Count: 5
#   ↪ Co-stem: خرج, Count: 5
#   ↪ Co-stem: احد, Count: 5
#   ↪ Co-stem: وهب, Count: 5
#   ↪ Co-stem: فوز, Count: 5
#   ↪ Co-stem: قبل, Count: 4
#   ↪ Co-stem: خلط, Count: 4
#   ↪ Co-stem: نوس, Count: 4
#   ↪ Co-stem: ثلث, Count: 4
#   ↪ Co-stem: بعل, Count: 4
#   ↪ Co-stem: عرف, Count: 4
#   ↪ Co-stem: كلم, Count: 4
#   ↪ Co-stem: نبا, Count: 4
#   ↪ Co-stem: وفي, Count: 4
#   ↪ Co-stem: بعض, Count: 4
#   ↪ Co-stem: نشز, Count: 4
#   ↪ Co-stem: خبر, Count: 4
#   ↪ Co-stem: زيد, Count: 4
#   ↪ Co-stem: اكل, Count: 4
#   ↪ Co-stem: موس, Count: 4
#   ↪ Co-stem: رجع, Count: 4
#   ↪ Co-stem: شرك, Count: 4
#   ↪ Co-stem: جمع, Count: 4
#   ↪ Co-stem: صبر, Count: 4
#   ↪ Co-stem: راي, Count: 4
#   ↪ Co-stem: طيب, Count: 4
#   ↪ Co-stem: وزع, Count: 4
#   ↪ Co-stem: كره, Count: 4
#   ↪ Co-stem: نور, Count: 4
#   ↪ Co-stem: فيا, Count: 4
#   ↪ Co-stem: هود, Count: 3
#   ↪ Co-stem: صحب, Count: 3
#   ↪ Co-stem: رغب, Count: 3
#   ↪ Co-stem: يتم, Count: 3
#   ↪ Co-stem: خلق, Count: 3
#   ↪ Co-stem: صلو, Count: 3
#   ↪ Co-stem: نهي, Count: 3
#   ↪ Co-stem: مول, Count: 3
#   ↪ Co-stem: سبل, Count: 3
#   ↪ Co-stem: علو, Count: 3
#   ↪ Co-stem: شقق, Count: 3
#   ↪ Co-stem: كثر, Count: 3
#   ↪ Co-stem: فعل, Count: 3
#   ↪ Co-stem: انث, Count: 3
#   ↪ Co-stem: حضر, Count: 3
#   ↪ Co-stem: شحح, Count: 3
#   ↪ Co-stem: عدل, Count: 3
#   ↪ Co-stem: الم, Count: 3
#   ↪ Co-stem: دون, Count: 3
#   ↪ Co-stem: نذر, Count: 3
#   ↪ Co-stem: جهل, Count: 3
#   ↪ Co-stem: بنو, Count: 3
#   ↪ Co-stem: ثمد, Count: 3
#   ↪ Co-stem: تمم, Count: 3
#   ↪ Co-stem: ربع, Count: 3
#   ↪ Co-stem: امم, Count: 3
#   ↪ Co-stem: ضيع, Count: 3
#   ↪ Co-stem: نفل, Count: 3
#   ↪ Co-stem: مدن, Count: 3
#   ↪ Co-stem: صوب, Count: 3
#   ↪ Co-stem: لقي, Count: 3
#   ↪ Co-stem: نوح, Count: 3
#   ↪ Co-stem: جوب, Count: 3
#   ↪ Co-stem: ثوب, Count: 3
#   ↪ Co-stem: سحق, Count: 3
#   ↪ Co-stem: كرم, Count: 3
#   ↪ Co-stem: قلب, Count: 3
#   ↪ Co-stem: بصر, Count: 3
#   ↪ Co-stem: سوي, Count: 3
#   ↪ Co-stem: منن, Count: 3
#   ↪ Co-stem: حمد, Count: 3
#   ↪ Co-stem: بول, Count: 3
#   ↪ Co-stem: طهر, Count: 2
#   ↪ Co-stem: صبا, Count: 2
#   ↪ Co-stem: اثم, Count: 2
#   ↪ Co-stem: عنت, Count: 2
#   ↪ Co-stem: سمع, Count: 2
#   ↪ Co-stem: قرا, Count: 2
#   ↪ Co-stem: ردد, Count: 2
#   ↪ Co-stem: رجل, Count: 2
#   ↪ Co-stem: درج, Count: 2
#   ↪ Co-stem: مهد, Count: 2
#   ↪ Co-stem: سرع, Count: 2
#   ↪ Co-stem: الل, Count: 2
#   ↪ Co-stem: نسو, Count: 2
#   ↪ Co-stem: نفق, Count: 2
#   ↪ Co-stem: قنت, Count: 2
#   ↪ Co-stem: حفظ, Count: 2
#   ↪ Co-stem: وعظ, Count: 2
#   ↪ Co-stem: ضرب, Count: 2
#   ↪ Co-stem: بعث, Count: 2
#   ↪ Co-stem: وفق, Count: 2
#   ↪ Co-stem: ظلل, Count: 2
#   ↪ Co-stem: نجو, Count: 2
#   ↪ Co-stem: ميل, Count: 2
#   ↪ Co-stem: وذر, Count: 2
#   ↪ Co-stem: دين, Count: 2
#   ↪ Co-stem: وجد, Count: 2
#   ↪ Co-stem: طمع, Count: 2
#   ↪ Co-stem: طعم, Count: 2
#   ↪ Co-stem: وسع, Count: 2
#   ↪ Co-stem: نوق, Count: 2
#   ↪ Co-stem: ضعف, Count: 2
#   ↪ Co-stem: ليل, Count: 2
#   ↪ Co-stem: عشر, Count: 2
#   ↪ Co-stem: وحد, Count: 2
#   ↪ Co-stem: مرر, Count: 2
#   ↪ Co-stem: ذنب, Count: 2
#   ↪ Co-stem: عسي, Count: 2
#   ↪ Co-stem: وطا, Count: 2
#   ↪ Co-stem: غيظ, Count: 2
#   ↪ Co-stem: نيل, Count: 2
#   ↪ Co-stem: عدو, Count: 2
#   ↪ Co-stem: عمر, Count: 2
#   ↪ Co-stem: رجو, Count: 2
#   ↪ Co-stem: نوب, Count: 2
#   ↪ Co-stem: جرم, Count: 2
#   ↪ Co-stem: لوط, Count: 2
#   ↪ Co-stem: وجه, Count: 2
#   ↪ Co-stem: اول, Count: 2
#   ↪ Co-stem: انت, Count: 2
#   ↪ Co-stem: لحق, Count: 2
#   ↪ Co-stem: عدن, Count: 2
#   ↪ Co-stem: اوب, Count: 2
#   ↪ Co-stem: بقي, Count: 2
#   ↪ Co-stem: كنز, Count: 2
#   ↪ Co-stem: ودد, Count: 2
#   ↪ Co-stem: يعق, Count: 2
#   ↪ Co-stem: نكح, Count: 2
#   ↪ Co-stem: غني, Count: 2
#   ↪ Co-stem: بدل, Count: 2
#   ↪ Co-stem: بسم, Count: 2
#   ↪ Co-stem: ضحك, Count: 2
#   ↪ Co-stem: جبر, Count: 2
#   ↪ Co-stem: غرف, Count: 2
#   ↪ Co-stem: روض, Count: 2
#   ↪ Co-stem: مكر, Count: 2
#   ↪ Co-stem: نعج, Count: 2
#   ↪ Co-stem: قلل, Count: 2
#   ↪ Co-stem: ركع, Count: 2
#   ↪ Co-stem: حسب, Count: 2
#   ↪ Co-stem: موت, Count: 2
#   ↪ Co-stem: انس, Count: 2
#   ↪ Co-stem: وضع, Count: 2
#   ↪ Co-stem: فصل, Count: 2
#   ↪ Co-stem: شهر, Count: 2
#   ↪ Co-stem: سنو, Count: 2
#   ↪ Co-stem: سجد, Count: 2
#   ↪ Co-stem: زرع, Count: 2
#   ↪ Co-stem: طوف, Count: 2
#   ↪ Co-stem: تلو, Count: 2
#   ↪ Co-stem: ظهر, Count: 2

# %%
# Co-Occured Variation Tokens

import json

# --- Load the Specific Stem Co-occurrence Data ---
with open(f"Output/{specific_root}_cooccurrence.json", "r", encoding="utf-8") as f:
    specific_root_data = json.load(f)

# --- Load the Normalized Unified Data ---
with open("Data/normalized_unified_quran_data.json", "r", encoding="utf-8") as f:
    normalized_data = json.load(f)

# --- Extract Unique Arabic Tokens and Verses for Each Co-occurring Stem ---
# Dictionaries to store:
#   - co_stem_to_tokens: a set of unique tokens for each co-occurring stem
#   - co_stem_to_verses: a list of verses (with IDs and full text) where that co-stem appears
co_stem_to_tokens = {}
co_stem_to_verses = {}

# First, extract the list of co-occurring stems from the specific stem data
cooccurring_stems = [entry["co-stem"] for entry in specific_root_data["cooccurrences"]]

# Process each verse in the normalized data
for verse in normalized_data:
    # Only consider verses that contain the specific stem (e.g., "صلح")
    roots = verse.get("arabic_roots", [])
    tokens = verse.get("normalized_tokens", [])
    if specific_root not in roots:
        continue

    # Retrieve verse data using the correct keys
    verse_text = verse.get("text", "").strip()
    surah = verse.get("surah", "Unknown")
    verse_number = verse.get("verse", "Unknown")
    verse_id = f"Surah {surah}, Verse {verse_number}"
    verse_info = f"ID: {verse_id} -> {verse_text}"

    # Loop over tokens and their corresponding roots in the verse
    for token, root in zip(tokens, roots):
        if root in cooccurring_stems:
            # Record the token
            if root not in co_stem_to_tokens:
                co_stem_to_tokens[root] = set()
            co_stem_to_tokens[root].add(token)

            # Record the verse info (avoiding duplicates)
            if root not in co_stem_to_verses:
                co_stem_to_verses[root] = []
            if verse_info not in co_stem_to_verses[root]:
                co_stem_to_verses[root].append(verse_info)

# Convert each token set to a sorted list for JSON compatibility
co_stem_to_tokens = {k: sorted(list(v)) for k, v in co_stem_to_tokens.items()}

# --- Update the Specific Stem Data with the Tokens ---
specific_root_data["co_occurring_tokens"] = co_stem_to_tokens

# --- Save the Updated Specific Stem Data ---
output_file = f"Output/{specific_root}_cooccurrence_with_tokens.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(specific_root_data, f, ensure_ascii=False, indent=4)

print(f"✅ Specific stem co-occurrence data with tokens saved to {output_file}")

# --- Print Preview (Tokens Only) ---
print("\n🔹 Unique Arabic Tokens for Each Co-occurring Stem:")
for co_stem, tokens in co_stem_to_tokens.items():
    print(f"Co-stem: {co_stem} -> Tokens: {tokens}")

# --- Create a Text Output File with Verses ---
txt_output_file = f"Output/{specific_root}_cooccurrence_tokens_and_verses.txt"
with open(txt_output_file, "w", encoding="utf-8") as f:
    for co_stem in sorted(co_stem_to_tokens.keys()):
        tokens_list = co_stem_to_tokens[co_stem]
        verses_list = co_stem_to_verses.get(co_stem, [])
        f.write(f"Co-stem: {co_stem} -> Tokens: {tokens_list}\n")
        f.write("          -> verses:\n")
        for verse in verses_list:
            f.write(f"             {verse}\n")
        f.write("\n")

print(f"✅ Text output saved to '{txt_output_file}'")
# Out:
# ✅ Specific stem co-occurrence data with tokens saved to Output/صلح_cooccurrence_with_tokens.json
#
# 🔹 Unique Arabic Tokens for Each Co-occurring Stem:
# Co-stem: قول -> Tokens: ['فقل', 'فيقول', 'قائلها', 'قال', 'قالوا', 'قل', 'قولا', 'قولها', 'قيل', 'قيلا', 'وسنقول', 'وقال', 'وقالوا', 'وقيل']
# Co-stem: فسد -> Tokens: ['المفسد', 'المفسدين', 'تفسدوا', 'كالمفسدين', 'يفسدون']
# Co-stem: ارض -> Tokens: ['ارض', 'ارضا', 'الارض', 'والارض']
# Co-stem: صلح -> Tokens: ['اصلاح', 'اصلاحا', 'اصلاحها', 'الاصلاح', 'الصالح', 'الصالحات', 'الصالحون', 'الصالحين', 'المصلح', 'المصلحين', 'بالصالحين', 'تصلحوا', 'صالح', 'صالحا', 'صالحين', 'صلح', 'صلحا', 'فاصلح', 'فاصلحوا', 'فالصالحات', 'مصلحون', 'واصلح', 'واصلحا', 'واصلحنا', 'واصلحوا', 'والصالحين', 'والصلح', 'وتصلحوا', 'وصالح', 'ويصلح', 'ياصالح', 'يصلح', 'يصلحا', 'يصلحون']
# Co-stem: بشر -> Tokens: ['بشر', 'مبشرين', 'وبشر', 'وبشرناه', 'ويبشر', 'يبشر', 'يبشرك']
# Co-stem: اللذ -> Tokens: ['الذي', 'الذين', 'بالذي', 'فالذين', 'كالذين', 'للذين', 'والذين']
# Co-stem: امن -> Tokens: ['ءامن', 'ءامنوا', 'ءامنون', 'المؤمنون', 'المؤمنين', 'امنا', 'بايمانهم', 'مؤمن', 'مؤمنا', 'مؤمنون', 'مؤمنين', 'نؤمن', 'وءامن', 'وءامنوا', 'يؤمن', 'يؤمنون']
# Co-stem: عمل -> Tokens: ['اعمالكم', 'اعمل', 'العاملين', 'تعملون', 'عمل', 'عملا', 'عملوا', 'فليعمل', 'نعمل', 'واعملوا', 'والعمل', 'وتعمل', 'وعمل', 'وعملوا', 'ويعمل', 'يعمل', 'يعملون']
# Co-stem: جنن -> Tokens: ['الجنات', 'الجنه', 'جنات']
# Co-stem: جري -> Tokens: ['تجري']
# Co-stem: تحت -> Tokens: ['تحت', 'تحته', 'تحتها', 'تحتهم']
# Co-stem: نهر -> Tokens: ['الانهار']
# Co-stem: كلل -> Tokens: ['كل', 'كلا', 'كلما', 'وكلا']
# Co-stem: رزق -> Tokens: ['رزقا', 'رزقنا', 'رزقناكم', 'رزقوا', 'ورزق', 'ورزقني', 'يرزقون']
# Co-stem: قبل -> Tokens: ['قبل', 'قبلهم']
# Co-stem: اتي -> Tokens: ['ءاتانا', 'ءاتاهما', 'ءاتيتنا', 'ءاتيتني', 'ائتنا', 'اوتوا', 'نؤتها', 'نؤتيه', 'وءاتوا', 'وءاتيناه', 'واتوا', 'يؤت', 'ياته', 'ياتي', 'ياتيانها', 'ياتينكم']
# Co-stem: زوج -> Tokens: ['ازواج', 'زوجه', 'زوجها', 'وازواجهم']
# Co-stem: طهر -> Tokens: ['مطهره']
# Co-stem: خلد -> Tokens: ['خالدون', 'خالدين']
# Co-stem: هود -> Tokens: ['هادوا', 'هود']
# Co-stem: نصر -> Tokens: ['نصير', 'نصيرا', 'والنصاري', 'وانتصروا']
# Co-stem: صبا -> Tokens: ['والصابءون', 'والصابءين']
# Co-stem: اله -> Tokens: ['الله', 'اله', 'الهكم', 'بالله', 'فلله', 'لله', 'والله']
# Co-stem: يوم -> Tokens: ['ليوم', 'واليوم', 'يوم', 'يومئذ']
# Co-stem: اخر -> Tokens: ['اخرتني', 'الءاخر', 'الءاخره', 'الاخري', 'وءاخر', 'وءاخرون', 'والءاخره']
# Co-stem: اجر -> Tokens: ['اجر', 'اجرا', 'اجره', 'اجرها', 'اجرهم', 'اجورهم', 'تاجرني', 'فاجره', 'واجر', 'واجرا']
# Co-stem: ربب -> Tokens: ['رب', 'ربك', 'ربكم', 'ربنا', 'ربه', 'ربهم', 'ربهما', 'ربي']
# Co-stem: خوف -> Tokens: ['تخافون', 'خاف', 'خافت', 'خفتم', 'خوف', 'خوفا', 'خوفهم', 'يخاف']
# Co-stem: حزن -> Tokens: ['يحزنون']
# Co-stem: صحب -> Tokens: ['اصحاب']
# Co-stem: رغب -> Tokens: ['رغبا', 'يرغب', 'يرغبوا']
# Co-stem: نفس -> Tokens: ['الانفس', 'بانفسهم', 'بانفسهن', 'فلانفسهم', 'فلنفسه', 'نفس', 'نفسا', 'نفسه', 'نفوسكم']
# Co-stem: دنو -> Tokens: ['الدنيا']
# Co-stem: توب -> Tokens: ['اتوب', 'التواب', 'تاب', 'تابا', 'تابوا', 'تبت', 'تتوبا', 'توابا', 'توبوا', 'متابا', 'يتوب']
# Co-stem: بين -> Tokens: ['المبين', 'بين', 'بينكم', 'بينه', 'بينهم', 'بينهما', 'مبينات', 'وبينوا']
# Co-stem: رحم -> Tokens: ['ارحامهن', 'الرحمن', 'الرحمه', 'الرحيم', 'برحمتك', 'برحمه', 'ترحمون', 'رحماء', 'رحمت', 'رحمتنا', 'رحمته', 'رحمه', 'رحيم', 'رحيما']
# Co-stem: وصي -> Tokens: ['موص', 'وتواصوا', 'ووصينا']
# Co-stem: اثم -> Tokens: ['اثم', 'اثما']
# Co-stem: غفر -> Tokens: ['غفور', 'غفورا', 'فاستغفر', 'فاستغفروه', 'لغفار', 'لغفور', 'مغفره', 'ويغفر']
# Co-stem: سال -> Tokens: ['اسءلكم', 'بسؤال', 'تسءلن', 'ويسءلونك', 'يسءلونك']
# Co-stem: يتم -> Tokens: ['اليتامي', 'يتيمين']
# Co-stem: خير -> Tokens: ['الخيرات', 'خير', 'وخير']
# Co-stem: خلط -> Tokens: ['الخلطاء', 'تخالطوهم', 'خلطوا']
# Co-stem: اخو -> Tokens: ['اخاهم', 'اخوه', 'اخوهم', 'اخويكم', 'فاخوانكم', 'لاخيه']
# Co-stem: علم -> Tokens: ['اتعلمون', 'اعلم', 'العلم', 'علم', 'عليم', 'عليما', 'وسيعلم', 'وعلمتني', 'يعلم']
# Co-stem: شيا -> Tokens: ['اشياءهم', 'شاء', 'شيئا', 'يشاءون']
# Co-stem: عنت -> Tokens: ['لاعنتكم']
# Co-stem: عزز -> Tokens: ['العزه', 'العزيز', 'عزيز']
# Co-stem: حكم -> Tokens: ['الحكيم', 'حكما', 'حكيم', 'وحكما', 'يحكم', 'يحكمون']
# Co-stem: جعل -> Tokens: ['تجعلوا', 'جعلا', 'جعلنا', 'سيجعل', 'فجعله', 'نجعل', 'نجعلهم', 'وجعل', 'وجعلنا']
# Co-stem: عرض -> Tokens: ['اعراضا', 'عرضه', 'فاعرضوا']
# Co-stem: وقي -> Tokens: ['اتقوا', 'اتقي', 'المتقين', 'تتقون', 'فاتقوا', 'واتقوا', 'وتتقوا']
# Co-stem: نوس -> Tokens: ['الناس']
# Co-stem: سمع -> Tokens: ['سميع', 'وسمعنا']
# Co-stem: ثلث -> Tokens: ['ثلاثه', 'ثلاثون', 'ثلاثين']
# Co-stem: قرا -> Tokens: ['القرءان', 'قروء']
# Co-stem: خلق -> Tokens: ['الخلق', 'خلق', 'خلقكم']
# Co-stem: كون -> Tokens: ['تكون', 'تكونوا', 'فكان', 'كان', 'كانت', 'كانتا', 'كانوا', 'كن', 'كنا', 'كنت', 'كنتم', 'لنكونن', 'واكن', 'وتكونوا', 'وكان', 'وكانوا', 'ولنكونن', 'يكون', 'يكونوا']
# Co-stem: بعل -> Tokens: ['بعلها', 'وبعولتهن']
# Co-stem: حقق -> Tokens: ['احق', 'الحق', 'بالحق', 'حقا']
# Co-stem: ردد -> Tokens: ['بردهن', 'مردا']
# Co-stem: رود -> Tokens: ['اتريد', 'اراد', 'ارادوا', 'اريد', 'تريد', 'فاراد', 'يريد', 'يريدا']
# Co-stem: مثل -> Tokens: ['مثل', 'مثلا', 'مثلكم', 'مثلها', 'مثلهم', 'ومثلهم']
# Co-stem: عرف -> Tokens: ['اعترفوا', 'بالمعروف', 'معروف']
# Co-stem: رجل -> Tokens: ['الرجال', 'وللرجال']
# Co-stem: درج -> Tokens: ['الدرجات', 'درجه']
# Co-stem: قوم -> Tokens: ['اقوم', 'القوم', 'قائم', 'قوامون', 'قوم', 'قوما', 'قومه', 'قومي', 'قيما', 'واقاموا', 'وياقوم', 'ياقوم']
# Co-stem: صلو -> Tokens: ['الصلوه', 'يصلي']
# Co-stem: ملك -> Tokens: ['الملائكه', 'الملك', 'والملائكه']
# Co-stem: هو -> Tokens: ['هو', 'وهو']
# Co-stem: حيي -> Tokens: ['الحيوه', 'بيحيي', 'تحيتهم', 'حيوه', 'فلنحيينه', 'محياهم', 'ويحيي', 'يحيي']
# Co-stem: صدق -> Tokens: ['اصدق', 'بصدقه', 'فاصدق', 'لنصدقن', 'مصدقا', 'والصديقين']
# Co-stem: كلم -> Tokens: ['الكلم', 'بكلمه', 'كلمه', 'ويكلم']
# Co-stem: نبا -> Tokens: ['النبوه', 'النبيين', 'نبيا', 'ونبيا']
# Co-stem: مهد -> Tokens: ['المهد', 'يمهدون']
# Co-stem: وفي -> Tokens: ['توفني', 'فاوفوا', 'فيوفيهم']
# Co-stem: حبب -> Tokens: ['يحب']
# Co-stem: ظلم -> Tokens: ['الظالمين', 'الظلمات', 'بظلام', 'بظلم', 'ظلما', 'ظلمك', 'ظلمه', 'ظلموا', 'للظالمين', 'يظلمون']
# Co-stem: بعد -> Tokens: ['ببعيد', 'بعد', 'بعده', 'بعدها']
# Co-stem: امر -> Tokens: ['امر', 'امرنا', 'امري', 'ويامرون']
# Co-stem: نهي -> Tokens: ['اتنهانا', 'انهاكم', 'وينهون']
# Co-stem: سرع -> Tokens: ['ويسارعون', 'يسارعون']
# Co-stem: الل -> Tokens: ['واللاتي', 'واللذان']
# Co-stem: نسو -> Tokens: ['النساء']
# Co-stem: فضل -> Tokens: ['الفضل', 'فضل', 'فضلا', 'فضله']
# Co-stem: بعض -> Tokens: ['بعض', 'بعضهم']
# Co-stem: نفق -> Tokens: ['انفقوا', 'وانفقوا']
# Co-stem: مول -> Tokens: ['المال', 'اموالكم', 'اموالهم']
# Co-stem: قنت -> Tokens: ['قانتات', 'يقنت']
# Co-stem: حفظ -> Tokens: ['حافظات', 'حفظ']
# Co-stem: نشز -> Tokens: ['نشوزا', 'نشوزهن']
# Co-stem: وعظ -> Tokens: ['اعظك', 'فعظوهن']
# Co-stem: ضرب -> Tokens: ['ضرب', 'واضربوهن']
# Co-stem: طوع -> Tokens: ['استطعت', 'اطعنكم', 'تستطيعوا', 'تسطع', 'واطيعوا', 'يطع']
# Co-stem: بغي -> Tokens: ['ابتغاء', 'بغت', 'تبغوا', 'تبغي', 'ليبغي', 'يبتغون']
# Co-stem: سبل -> Tokens: ['سبيل', 'سبيلا']
# Co-stem: علو -> Tokens: ['العلي', 'عليا', 'فتعالي']
# Co-stem: كبر -> Tokens: ['استكبروا', 'الكبير', 'كبير', 'كبيرا', 'واستكبروا']
# Co-stem: شقق -> Tokens: ['اشق', 'شقاق', 'شقاقي']
# Co-stem: بعث -> Tokens: ['فابعثوا', 'يبعثون']
# Co-stem: اهل -> Tokens: ['اهلك', 'اهله', 'اهلها', 'لاهل', 'واهلها']
# Co-stem: وفق -> Tokens: ['توفيقي', 'يوفق']
# Co-stem: خبر -> Tokens: ['خبيرا']
# Co-stem: دخل -> Tokens: ['ادخلا', 'الداخلين', 'سندخلهم', 'فيدخلهم', 'لندخلنهم', 'وادخل', 'وادخلناه', 'وادخلناهم', 'وادخلني', 'وادخلهم', 'وندخلهم', 'ويدخله', 'يدخل', 'يدخلنا', 'يدخله', 'يدخلون', 'يدخلونها']
# Co-stem: ابد -> Tokens: ['ابدا']
# Co-stem: ظلل -> Tokens: ['ظلا', 'ظليلا']
# Co-stem: رسل -> Tokens: ['ارسل', 'ارسلنا', 'الرسل', 'المرسلين', 'رسل', 'رسول', 'رسولا', 'مرسل', 'نرسل', 'والرسول', 'ورسوله']
# Co-stem: نعم -> Tokens: ['الانعام', 'النعيم', 'انعم', 'انعمت', 'نعم', 'نعمتك']
# Co-stem: حسن -> Tokens: ['احسانا', 'احسن', 'الحسني', 'المحسنين', 'باحسن', 'بالحسنات', 'تحسنوا', 'حسنا', 'حسنات', 'حسنه', 'واحسنوا', 'وحسن']
# Co-stem: كثر -> Tokens: ['كثير', 'كثيرا']
# Co-stem: نجو -> Tokens: ['نجواهم', 'نجينا']
# Co-stem: فعل -> Tokens: ['فعلته', 'يفعل']
# Co-stem: رضو -> Tokens: ['ارتضي', 'ترضاه', 'مرضات', 'ورضوانا']
# Co-stem: عظم -> Tokens: ['العظيم', 'عظيم', 'عظيما']
# Co-stem: وعد -> Tokens: ['تعدنا', 'وعد', 'وعدتهم', 'وواعدنا']
# Co-stem: ذكر -> Tokens: ['الذكر', 'تتذكرون', 'تذكر', 'ذكر', 'وذكروا', 'يتذكر']
# Co-stem: انث -> Tokens: ['انثي']
# Co-stem: مرا -> Tokens: ['امرات', 'امراه', 'وامرات']
# Co-stem: جنح -> Tokens: ['جناح']
# Co-stem: حضر -> Tokens: ['واحضرت']
# Co-stem: شحح -> Tokens: ['الشح']
# Co-stem: عدل -> Tokens: ['بالعدل', 'تعدلوا']
# Co-stem: ميل -> Tokens: ['الميل', 'تميلوا']
# Co-stem: وذر -> Tokens: ['فتذروها', 'فذروها']
# Co-stem: دين -> Tokens: ['دينهم']
# Co-stem: زيد -> Tokens: ['نزد', 'ويزيد', 'ويزيدهم']
# Co-stem: عذب -> Tokens: ['عذاب', 'عذابا', 'فيعذبهم', 'وعذاب']
# Co-stem: الم -> Tokens: ['اليم', 'اليما']
# Co-stem: وجد -> Tokens: ['ستجدني', 'يجدون']
# Co-stem: دون -> Tokens: ['دون']
# Co-stem: ولي -> Tokens: ['مولاه', 'وليا', 'وليي', 'يتولي']
# Co-stem: جيا -> Tokens: ['جئتم', 'جاء', 'جاءتكم', 'جاءك', 'جاءنا', 'وجاءكم']
# Co-stem: طمع -> Tokens: ['وطمعا', 'ونطمع']
# Co-stem: طعم -> Tokens: ['طعموا']
# Co-stem: نذر -> Tokens: ['النذير', 'لينذر', 'ومنذرين']
# Co-stem: ايا -> Tokens: ['ءايات', 'ءاياتي', 'ءايه', 'بءاياتنا']
# Co-stem: سلم -> Tokens: ['المسلمين', 'سلام', 'مسلما']
# Co-stem: كتب -> Tokens: ['الكتاب', 'بالكتاب', 'كاتبون', 'كتب', 'كتبنا', 'والكتاب']
# Co-stem: سوا -> Tokens: ['اساء', 'السوء', 'السيئات', 'المسيء', 'بسوء', 'ساء', 'سوءا', 'سيئا', 'سيئاته', 'سيئاتهم', 'سيئه', 'والسيئات']
# Co-stem: جهل -> Tokens: ['الجاهلين', 'بجهاله']
# Co-stem: بنو -> Tokens: ['ابنتي', 'والبنون', 'يابني']
# Co-stem: وسع -> Tokens: ['واسع', 'وسعها']
# Co-stem: دعو -> Tokens: ['تدعونا', 'دعا', 'دعوا', 'وادعوه', 'ويدعوننا']
# Co-stem: قرب -> Tokens: ['القربي', 'تقربكم', 'قريب']
# Co-stem: ثمد -> Tokens: ['ثمود']
# Co-stem: عبد -> Tokens: ['اعبدوا', 'بعباده', 'عبادك', 'عبادكم', 'عبادنا', 'عباده', 'عبادي', 'عبدين', 'للعبيد', 'نعبد', 'يعبد', 'يعبدونني']
# Co-stem: غير -> Tokens: ['بغير', 'غير', 'غيره']
# Co-stem: نوق -> Tokens: ['الناقه', 'ناقه']
# Co-stem: اكل -> Tokens: ['تاكل', 'كلوا', 'وياكلون']
# Co-stem: ضعف -> Tokens: ['استضعفوا', 'الضعف']
# Co-stem: موس -> Tokens: ['موسي', 'ياموسي']
# Co-stem: ليل -> Tokens: ['ليله']
# Co-stem: تمم -> Tokens: ['اتممت', 'فتم', 'واتممناها']
# Co-stem: عشر -> Tokens: ['بعشر', 'عشرا']
# Co-stem: ربع -> Tokens: ['اربعين']
# Co-stem: خلف -> Tokens: ['اخالفكم', 'اخلفني', 'استخلف', 'ليستخلفنهم', 'يتخلفوا']
# Co-stem: امم -> Tokens: ['امما', 'امه']
# Co-stem: رجع -> Tokens: ['ترجعون', 'فارجعنا', 'مرجعكم', 'يرجعون']
# Co-stem: ضيع -> Tokens: ['نضيع', 'يضيع']
# Co-stem: وحد -> Tokens: ['واحد', 'واحده']
# Co-stem: حمل -> Tokens: ['حملا', 'حملت', 'حملته', 'وحمله']
# Co-stem: مرر -> Tokens: ['فمرت', 'مرتين']
# Co-stem: شكر -> Tokens: ['اشكر', 'الشاكرين', 'شكور']
# Co-stem: شرك -> Tokens: ['شركاء', 'يشرك', 'يشركون']
# Co-stem: نزل -> Tokens: ['نزل', 'نزلا']
# Co-stem: نفل -> Tokens: ['الانفال', 'نافله']
# Co-stem: ذنب -> Tokens: ['بذنوبهم', 'ذنوبكم']
# Co-stem: عسي -> Tokens: ['عسي', 'فعسي']
# Co-stem: مدن -> Tokens: ['المدينه']
# Co-stem: صوب -> Tokens: ['اصاب', 'يصيبكم', 'يصيبهم']
# Co-stem: وطا -> Tokens: ['موطئا', 'يطئون']
# Co-stem: غيظ -> Tokens: ['ليغيظ', 'يغيظ']
# Co-stem: كفر -> Tokens: ['الكافرين', 'الكفار', 'كفر', 'كفران', 'كفره', 'كفروا', 'لنكفرن', 'والكافرون', 'يكفر', 'يكفرون']
# Co-stem: نيل -> Tokens: ['نيلا', 'ينالون']
# Co-stem: عدو -> Tokens: ['عدو']
# Co-stem: جمع -> Tokens: ['الجمع', 'جميعا', 'يجمعكم']
# Co-stem: جزي -> Tokens: ['جزاء', 'ليجزي', 'وجزؤا', 'ولنجزينهم', 'يجزي']
# Co-stem: قسط -> Tokens: ['المقسطين', 'بالقسط', 'واقسطوا']
# Co-stem: هدي -> Tokens: ['اهتدوا', 'اهتدي', 'سيهديهم', 'هدي', 'يهدي', 'يهديهم']
# Co-stem: لقي -> Tokens: ['القوا', 'لقاء', 'يلقاها']
# Co-stem: صبر -> Tokens: ['الصابرون', 'بالصبر', 'صبرا', 'صبروا']
# Co-stem: نوح -> Tokens: ['نوح', 'يانوح']
# Co-stem: عمر -> Tokens: ['نعمركم', 'واستعمركم']
# Co-stem: جوب -> Tokens: ['فاستجبنا', 'مجيب', 'ويستجيب']
# Co-stem: رجو -> Tokens: ['مرجوا', 'يرجوا']
# Co-stem: ابو -> Tokens: ['ءاباؤنا', 'ءابائهم', 'ابوهما', 'ابيكم']
# Co-stem: راي -> Tokens: ['ارءيتم', 'تراهم', 'تري']
# Co-stem: نوب -> Tokens: ['انيب', 'واناب']
# Co-stem: جرم -> Tokens: ['المجرمون', 'يجرمنكم']
# Co-stem: لوط -> Tokens: ['لوط']
# Co-stem: قتل -> Tokens: ['اقتتلوا', 'اقتلوا', 'تقتلني', 'فقاتلوا', 'قتلت']
# Co-stem: وجه -> Tokens: ['وجه', 'وجوههم']
# Co-stem: اول -> Tokens: ['تاويل']
# Co-stem: انت -> Tokens: ['انت']
# Co-stem: لحق -> Tokens: ['والحقني']
# Co-stem: عدن -> Tokens: ['عدن']
# Co-stem: ذرر -> Tokens: ['ذريته', 'ذريتي', 'وذرياتهم']
# Co-stem: طيب -> Tokens: ['الطيب', 'الطيبات', 'طوبي', 'طيبه']
# Co-stem: اوب -> Tokens: ['للاوابين', 'مءاب']
# Co-stem: اللت -> Tokens: ['التي', 'بالتي', 'للتي']
# Co-stem: شدد -> Tokens: ['اشداء', 'اشده', 'اشدهما', 'شديد', 'شديدا']
# Co-stem: بقي -> Tokens: ['والباقيات']
# Co-stem: ثوب -> Tokens: ['ثواب', 'ثوابا']
# Co-stem: كنز -> Tokens: ['كنز', 'كنزهما']
# Co-stem: بلغ -> Tokens: ['بلغ', 'وبلغ', 'يبلغا']
# Co-stem: خرج -> Tokens: ['اخرج', 'اخرجنا', 'ليخرج', 'ويستخرجا']
# Co-stem: احد -> Tokens: ['احدا', 'احداهما', 'احدكم', 'احدي']
# Co-stem: ودد -> Tokens: ['الموده', 'ودا']
# Co-stem: وهب -> Tokens: ['هب', 'ووهبنا']
# Co-stem: سحق -> Tokens: ['اسحاق', 'باسحاق']
# Co-stem: يعق -> Tokens: ['ويعقوب']
# Co-stem: كرم -> Tokens: ['كريم', 'كريما']
# Co-stem: نكح -> Tokens: ['انكحك', 'وانكحوا']
# Co-stem: غني -> Tokens: ['يغنهم', 'يغنيا']
# Co-stem: بدل -> Tokens: ['وليبدلنهم', 'يبدل']
# Co-stem: قلب -> Tokens: ['قلوبكما', 'منقلب', 'ينقلبون']
# Co-stem: بسم -> Tokens: ['فتبسم']
# Co-stem: ضحك -> Tokens: ['ضاحكا']
# Co-stem: وزع -> Tokens: ['اوزعني']
# Co-stem: ولد -> Tokens: ['اولادكم', 'بوالديه', 'والدي']
# Co-stem: جبر -> Tokens: ['جبارا', 'وجبريل']
# Co-stem: غرف -> Tokens: ['الغرفات', 'غرفا']
# Co-stem: روض -> Tokens: ['روضات', 'روضه']
# Co-stem: بصر -> Tokens: ['ابصرنا', 'بصير', 'والبصير']
# Co-stem: فوز -> Tokens: ['الفوز', 'فاز', 'فوزا']
# Co-stem: مكر -> Tokens: ['ومكر', 'يمكرون']
# Co-stem: نعج -> Tokens: ['نعاجه', 'نعجتك']
# Co-stem: قلل -> Tokens: ['قليلا', 'وقليل']
# Co-stem: ركع -> Tokens: ['راكعا', 'ركعا']
# Co-stem: حسب -> Tokens: ['حساب', 'حسب']
# Co-stem: سوي -> Tokens: ['سواء', 'فاستوي', 'يستوي']
# Co-stem: منن -> Tokens: ['ممنون']
# Co-stem: موت -> Tokens: ['الموت', 'ومماتهم']
# Co-stem: انس -> Tokens: ['الانسان']
# Co-stem: كره -> Tokens: ['كرها']
# Co-stem: وضع -> Tokens: ['ووضعته']
# Co-stem: فصل -> Tokens: ['وفصاله']
# Co-stem: شهر -> Tokens: ['شهرا']
# Co-stem: سنو -> Tokens: ['سنه']
# Co-stem: حمد -> Tokens: ['محمد']
# Co-stem: بول -> Tokens: ['بالهم']
# Co-stem: نور -> Tokens: ['النار', 'النور', 'والنار']
# Co-stem: سجد -> Tokens: ['السجود', 'سجدا']
# Co-stem: زرع -> Tokens: ['الزراع', 'كزرع']
# Co-stem: طوف -> Tokens: ['طائفتان']
# Co-stem: فيا -> Tokens: ['تفيء', 'فاءت']
# Co-stem: تلو -> Tokens: ['يتلوا']
# Co-stem: ظهر -> Tokens: ['تظاهرا', 'ظهير']
# ✅ Text output saved to 'Output/صلح_cooccurrence_tokens_and_verses.txt'

# %%
# Co-occurred Root Embeddings

import json
import numpy as np

cooccurrence_file = f"Output/{specific_root}_cooccurrence.json"
embedding_file = "Data/final_root_embeddings.json"

# --- Load Embeddings ---
with open(embedding_file, "r", encoding="utf-8") as f:
    all_embeddings = json.load(f)

# --- Load Co-occurrence Data ---
with open(cooccurrence_file, "r", encoding="utf-8") as f:
    co_data = json.load(f)

# --- Collect all relevant roots: main root + co-occurring ones ---
related_roots = {specific_root}
related_roots.update([entry["co-stem"] for entry in co_data.get("cooccurrences", [])])

# --- Extract embeddings for the selected roots ---
filtered_roots = []
filtered_embeddings = []

for root in related_roots:
    embedding = all_embeddings.get(root)
    if embedding:
        filtered_roots.append(root)
        filtered_embeddings.append(embedding)

filtered_embeddings = np.array(filtered_embeddings)

# --- Save for later clustering ---
np.save(f"Output/{specific_root}_embeddings_with_cooccur.npy", filtered_embeddings)
with open(f"Output/{specific_root}_roots_with_cooccur.json", "w", encoding="utf-8") as f:
    json.dump(filtered_roots, f, ensure_ascii=False, indent=4)

print(f"✅ Extracted {len(filtered_roots)} roots for '{specific_root}' including co-occurrences.")
print(f"🔹 Saved embeddings to '{specific_root}_embeddings_with_cooccur.npy'")
print(f"🔹 Saved root names to '{specific_root}_roots_with_cooccur.json'")
# Out:
# ✅ Extracted 248 roots for 'صلح' including co-occurrences.
# 🔹 Saved embeddings to 'صلح_embeddings_with_cooccur.npy'
# 🔹 Saved root names to 'صلح_roots_with_cooccur.json'

# %%
# Dimension Reduction

import umap
import numpy as np
import os
import json

# --- Configuration ---
input_embedding_file = f"Output/{specific_root}_embeddings_with_cooccur.npy"
output_embedding_file = f"Output/{specific_root}_reduced_embeddings_with_cooccur.npy"
roots_file = f"Output/{specific_root}_roots_with_cooccur.json"  # optional file with root names

# --- Load Embeddings ---
if not os.path.exists(input_embedding_file):
    raise FileNotFoundError(f"Embedding file not found: {input_embedding_file}")

embeddings = np.load(input_embedding_file)
print(f"✅ Loaded embeddings for root '{specific_root}' with shape {embeddings.shape}")

# --- Determine Number of Roots ---
# Option 1: Use the roots file if it exists
if os.path.exists(roots_file):
    with open(roots_file, "r", encoding="utf-8") as f:
        roots = json.load(f)
    num_roots = len(roots)
    print(f"✅ Loaded {num_roots} roots from '{roots_file}'")
else:
    # Option 2: Fallback to using the number of rows in the embeddings
    num_roots = embeddings.shape[0]
    print("⚠️ Roots file not found, using embeddings shape as count.")

# --- Set n_reduced_dimensions ---
if num_roots >= 100:
    n_reduced_dimensions = 100
else:
    n_reduced_dimensions = num_roots - 3

if n_reduced_dimensions < 1:
    raise ValueError("Computed n_reduced_dimensions is less than 1. Check your data.")

print(f"Setting n_reduced_dimensions to: {n_reduced_dimensions}")

# --- Apply UMAP for Dimensionality Reduction ---
umap_reducer = umap.UMAP(n_components=n_reduced_dimensions, random_state=42)
reduced_embeddings = umap_reducer.fit_transform(embeddings)

# --- Save Reduced Embeddings ---
np.save(output_embedding_file, reduced_embeddings)
print(f"✅ Saved reduced embeddings to '{output_embedding_file}'")

# --- Summary ---
print(f"Original dimensions: {embeddings.shape[1]}")
print(f"Reduced dimensions: {reduced_embeddings.shape[1]} (via UMAP with n_components={n_reduced_dimensions})")
# Out:
# ✅ Loaded embeddings for root 'صلح' with shape (248, 768)
# ✅ Loaded 248 roots from 'Output/صلح_roots_with_cooccur.json'
# Setting n_reduced_dimensions to: 100
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ✅ Saved reduced embeddings to 'Output/صلح_reduced_embeddings_with_cooccur.npy'
# Original dimensions: 768
# Reduced dimensions: 100 (via UMAP with n_components=100)

# %%
# Hierarchical Clustering Heatmap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from scipy.cluster.hierarchy import linkage, fcluster, leaves_list
import os

# --- Config ---
embedding_file = f"Output/{specific_root}_reduced_embeddings_with_cooccur.npy"
roots_file = f"Output/{specific_root}_roots_with_cooccur.json"
heatmap_output = f"Output/{specific_root}_hierarchical_clustered_heatmap.png"
cluster_json_output = f"Output/{specific_root}_hierarchical_clusters.json"
default_clusters = 10  # Default clustering value for initial visualization

# --- Load Reduced Embeddings ---
if not os.path.exists(embedding_file):
    raise FileNotFoundError(f"Embedding file '{embedding_file}' not found.")

embeddings = np.load(embedding_file)
print(f"✅ Loaded reduced embeddings with shape {embeddings.shape} from '{embedding_file}'.")

# --- Load Root Labels ---
with open(roots_file, "r", encoding="utf-8") as f:
    roots = json.load(f)
print(f"✅ Loaded {len(roots)} roots from '{roots_file}'.")

if len(roots) != embeddings.shape[0]:
    print("⚠ Number of roots does not match embedding count. Generating default labels.")
    roots = [f"Root {i+1}" for i in range(embeddings.shape[0])]

# --- Hierarchical Clustering ---
linkage_matrix = linkage(embeddings, method='ward')
ordered_indices = leaves_list(linkage_matrix)

# Compute default cluster labels (for visual inspection)
cluster_labels_default = fcluster(linkage_matrix, default_clusters, criterion='maxclust')
sorted_labels_default = cluster_labels_default[ordered_indices]

# --- Reorder Everything Based on Clustering ---
sorted_embeddings = embeddings[ordered_indices]
sorted_roots = [roots[i] for i in ordered_indices]

# --- Prepare Heatmap Data ---
heatmap_data = pd.DataFrame(sorted_embeddings, index=sorted_roots)

# --- Plot Heatmap with Default Clusters (for inspection only) ---
plt.figure(figsize=(25, 15))
ax = sns.heatmap(heatmap_data.T, cmap="magma")
ax.set_title(f"Hierarchical Heatmap for '{specific_root}' (Default {default_clusters} Clusters)", fontsize=14)
ax.set_xlabel("Roots Sorted by Similarity")
ax.set_ylabel("Embedding Dimensions")

# Draw cluster boundaries for default clusters
cluster_boundaries = []
prev_label = sorted_labels_default[0]
for i, label in enumerate(sorted_labels_default):
    if label != prev_label:
        cluster_boundaries.append(i)
        prev_label = label
cluster_boundaries.append(len(sorted_roots))

line_colors = ["black", "white"]
for i in range(len(cluster_boundaries) - 1):
    start = cluster_boundaries[i]
    end = cluster_boundaries[i + 1]
    ax.hlines(-5, start, end, colors=line_colors[i % 2], linewidth=4)
    ax.text((start + end) / 2, -8, f"{i+1}", ha="center", va="center", fontsize=12, color=line_colors[i % 2])

ax.set_xlim([0, len(sorted_roots)])
ax.set_ylim([-10, heatmap_data.shape[1]])
plt.show()
plt.close()

# --- Ask User for New Number of Clusters ---
user_input = input(f"Enter desired number of clusters based on the above visualization (press Enter to keep default of {default_clusters}): ")
if user_input.strip() == "":
    final_clusters = default_clusters
else:
    try:
        final_clusters = int(user_input)
    except ValueError:
        print(f"Invalid input. Using default value of {default_clusters}.")
        final_clusters = default_clusters

# --- Recompute Cluster Labels Using User-Defined Number ---
cluster_labels = fcluster(linkage_matrix, final_clusters, criterion='maxclust')
sorted_labels = cluster_labels[ordered_indices]

# --- Replot Final Heatmap with Updated Clusters ---
plt.figure(figsize=(25, 15))
ax = sns.heatmap(heatmap_data.T, cmap="magma")
ax.set_title(f"Hierarchical Heatmap for '{specific_root}' ({final_clusters} Clusters)", fontsize=14)
ax.set_xlabel("Roots Sorted by Similarity")
ax.set_ylabel("Embedding Dimensions")

# Draw updated cluster boundaries
cluster_boundaries = []
prev_label = sorted_labels[0]
for i, label in enumerate(sorted_labels):
    if label != prev_label:
        cluster_boundaries.append(i)
        prev_label = label
cluster_boundaries.append(len(sorted_roots))

for i in range(len(cluster_boundaries) - 1):
    start = cluster_boundaries[i]
    end = cluster_boundaries[i + 1]
    ax.hlines(-5, start, end, colors=line_colors[i % 2], linewidth=4)
    ax.text((start + end) / 2, -8, f"{i+1}", ha="center", va="center", fontsize=12, color=line_colors[i % 2])

ax.set_xlim([0, len(sorted_roots)])
ax.set_ylim([-10, heatmap_data.shape[1]])

# Save only the final heatmap to the output file
plt.savefig(heatmap_output, dpi=600, bbox_inches="tight")
plt.show()
plt.close()
print(f"✅ Final heatmap saved to '{heatmap_output}'.")

# --- Save Human-Readable Cluster Assignments ---
clusters = {}
for i, label in enumerate(sorted_labels):
    cluster_key = f"Cluster {label}"
    clusters.setdefault(cluster_key, []).append(sorted_roots[i])

with open(cluster_json_output, "w", encoding="utf-8") as f:
    json.dump(clusters, f, ensure_ascii=False, indent=4)
print(f"✅ Saved hierarchical clustering results to '{cluster_json_output}'.")
# Out:
# ✅ Loaded reduced embeddings with shape (248, 100) from 'Output/صلح_reduced_embeddings_with_cooccur.npy'.
# ✅ Loaded 248 roots from 'Output/صلح_roots_with_cooccur.json'.
# Enter desired number of clusters based on the above visualization (press Enter to keep default of 10): 20
# ✅ Final heatmap saved to 'Output/صلح_hierarchical_clustered_heatmap.png'.
# ✅ Saved hierarchical clustering results to 'Output/صلح_hierarchical_clusters.json'.

# %%
# Scatter Plot

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import json
import os
from sklearn.manifold import TSNE
from scipy.spatial.distance import pdist, squareform
import arabic_reshaper
from bidi.algorithm import get_display
from adjustText import adjust_text

# ---------------------------
# 1. Setup filenames
# ---------------------------
embedding_file = f"output/{specific_root}_reduced_embeddings_with_cooccur.npy"
roots_file = f"output/{specific_root}_roots_with_cooccur.json"
cooccurrence_file = f"output/{specific_root}_cooccurrence.json"
clusters_file = f"output/{specific_root}_hierarchical_clusters.json"

# ---------------------------
# 2. Load data files
# ---------------------------
if os.path.exists(embedding_file):
    embeddings = np.load(embedding_file)
    print(f"✅ Loaded embeddings from '{embedding_file}' with shape {embeddings.shape}")
    # Check if the number of dimensions is below 50.
    if embeddings.shape[1] < 50:
        print(f"⚠ Reduced dimensions ({embeddings.shape[1]}) below 50, switching to original embeddings.")
        embedding_file = f"output/{specific_root}_embeddings_with_cooccur.npy"
        if os.path.exists(embedding_file):
            embeddings = np.load(embedding_file)
            print(f"✅ Loaded original embeddings from '{embedding_file}' with shape {embeddings.shape}")
        else:
            raise FileNotFoundError(f"Original embeddings file not found: '{embedding_file}'")
else:
    raise FileNotFoundError(f"Embeddings file not found: '{embedding_file}'")

with open(roots_file, "r", encoding="utf-8") as f:
    roots_list = json.load(f)

with open(cooccurrence_file, "r", encoding="utf-8") as f:
    co_data = json.load(f)

# Load co-stem frequencies and include total_occurrences of the specific root
root_frequencies = {entry["co-stem"]: entry["count"] for entry in co_data.get("cooccurrences", [])}
if "total_occurrences" in co_data:
    root_frequencies[specific_root] = co_data["total_occurrences"]
    print(f"📊 Total frequency of '{specific_root}': {co_data['total_occurrences']}")
else:
    root_frequencies[specific_root] = 1
    print(f"⚠ '{specific_root}' total_occurrences not found, fallback = 1")

with open(clusters_file, "r", encoding="utf-8") as f:
    cluster_data = json.load(f)

# ---------------------------
# 3. Build cluster mappings
# ---------------------------
root_to_cluster = {}
for label, stems_dict in cluster_data.items():
    try:
        cluster_id = int(label.split()[1])
    except:
        cluster_id = -1
    for root in stems_dict:
        root_to_cluster[root] = cluster_id

# ---------------------------
# 4. Filter roots to plot
# ---------------------------
valid_roots, valid_indices, frequencies, cluster_ids = [], [], [], []
for i, root in enumerate(roots_list):
    if root in root_to_cluster and root in root_frequencies:
        valid_roots.append(root)
        valid_indices.append(i)
        frequencies.append(root_frequencies[root])
        cluster_ids.append(root_to_cluster[root])
    else:
        print(f"⚠ Skipping '{root}' — missing cluster or frequency")

if not valid_indices:
    raise ValueError("No valid roots to plot.")

# ---------------------------
# 5. Dimensionality Reduction (Stable Layout)
# ---------------------------
selected_embeddings = embeddings[valid_indices]
distance_matrix = squareform(pdist(selected_embeddings, metric="euclidean"))

# --- User Input for TSNE Parameters ---
default_perplexity = min(30, max(2, len(valid_indices) - 1))
print(f"Current perplexity: {default_perplexity}")
user_input_perplexity = input(f"Enter desired perplexity (default {default_perplexity}): ")
if user_input_perplexity.strip() == "":
    perplexity = default_perplexity
else:
    try:
        perplexity = float(user_input_perplexity)
        # Ensure perplexity is within valid range
        if perplexity < 2:
            perplexity = 2
        elif perplexity > len(valid_indices) - 1:
            perplexity = len(valid_indices) - 1
    except Exception as e:
        print("Invalid input. Using default perplexity.")
        perplexity = default_perplexity
print(f"Using perplexity: {perplexity}")

tsne = TSNE(
    n_components=2,
    metric="precomputed",
    init="random",  # required with precomputed distance matrix
    random_state=42,
    perplexity=perplexity,
    max_iter=500
)
tsne_coords = tsne.fit_transform(distance_matrix)
print("✅ TSNE completed. TSNE coordinates shape:", tsne_coords.shape)

# --- Option 1: Normalize and Expand with Padding ---
x = tsne_coords[:, 0]
y = tsne_coords[:, 1]

# Center around 0 and scale to [-0.6, 0.6]
x = (x - x.mean()) / (x.ptp()) * 1.2
y = (y - y.mean()) / (y.ptp()) * 1.2

# Translate to [0, 1] with padding
x = x - x.min()
y = y - y.min()
x = x / x.max()
y = y / y.max()

norm_coords = np.column_stack((x, y))

# ---------------------------
# 5b. Repulsion-Based Spacing Adjustment (Soft Relaxation)
# ---------------------------
def apply_min_distance_spacing(coords, min_dist=0.02, steps=10, lr=0.01):
    coords = coords.copy()
    for step in range(steps):
        for i in range(len(coords)):
            for j in range(i + 1, len(coords)):
                dx, dy = coords[i] - coords[j]
                dist = np.sqrt(dx**2 + dy**2)
                if dist < min_dist:
                    force = (min_dist - dist) * lr
                    direction = np.array([dx, dy]) / (dist + 1e-5)
                    coords[i] += direction * force
                    coords[j] -= direction * force
        # Normalize again to [0, 1] each step to keep it bounded
        coords = coords - coords.min(axis=0)
        coords = coords / coords.max(axis=0)
    return coords

norm_coords = apply_min_distance_spacing(norm_coords, min_dist=0.04, steps=20, lr=0.06)
print("✅ Coordinates adjusted with repulsion spacing.")

# ---------------------------
# 6. Cluster Colors
# ---------------------------
unique_clusters = sorted(set(cluster_ids))
cmap = plt.get_cmap("gist_ncar", len(unique_clusters))

def luminance(color):  # perceived brightness
    r, g, b = mcolors.to_rgb(color)
    return 0.2126 * r + 0.7152 * g + 0.0722 * b

def darken(color, factor=0.7):
    return tuple(np.clip(factor * c, 0, 1) for c in mcolors.to_rgb(color))

def adjust_color(color, threshold=0.65):
    return darken(color) if luminance(color) > threshold else color

cluster_to_color = {cid: adjust_color(cmap(i)) for i, cid in enumerate(unique_clusters)}

# ---------------------------
# 7. Scatter Plot with User-Defined Text Parameters
# ---------------------------
# Ask for base_fontsize and scale_factor
default_base_fontsize = 5
default_scale_factor = 0.2
print(f"Current base_fontsize: {default_base_fontsize}, scale_factor: {default_scale_factor}")
user_base_fontsize = input(f"Enter desired base_fontsize (default {default_base_fontsize}): ")
if user_base_fontsize.strip() == "":
    base_fontsize = default_base_fontsize
else:
    try:
        base_fontsize = float(user_base_fontsize)
    except Exception as e:
        print("Invalid input. Using default base_fontsize.")
        base_fontsize = default_base_fontsize

user_scale_factor = input(f"Enter desired scale_factor (default {default_scale_factor}): ")
if user_scale_factor.strip() == "":
    scale_factor = default_scale_factor
else:
    try:
        scale_factor = float(user_scale_factor)
    except Exception as e:
        print("Invalid input. Using default scale_factor.")
        scale_factor = default_scale_factor

print(f"Using base_fontsize: {base_fontsize}, scale_factor: {scale_factor}")

plt.figure(figsize=(10, 8))
texts = []

for i, (x, y) in enumerate(norm_coords):
    root = valid_roots[i]
    freq = frequencies[i]
    cid = cluster_ids[i]

    font_size = base_fontsize + scale_factor * freq
    label = get_display(arabic_reshaper.reshape(root))
    color = cluster_to_color.get(cid, "black")
    text = plt.text(x, y, label, fontsize=font_size, color=color, alpha=0.85)
    texts.append(text)

adjust_text(
    texts,
    only_move={'text': 'xy'},
    force_text=70,
    force_points=0.7,
    expand_text=(1.05, 1.2),
    expand_points=(1.05, 1.2),
    arrowprops=dict(arrowstyle="-", color='grey', lw=0.5, alpha=0.0)
)

title_ar = get_display(arabic_reshaper.reshape(specific_root))
plt.title(f"Scatter Plot of Roots Co-occurring with '{title_ar}'", fontsize=16)
plt.xlabel("t-SNE X")
plt.ylabel("t-SNE Y")
plt.grid(True)
plt.xlim(0, 1)
plt.ylim(0, 1)

output_file = f"output/{specific_root}_scatter_cooccur_roots.png"
plt.savefig(output_file, dpi=600, bbox_inches="tight")
plt.show()
print(f"✅ Saved final plot to '{output_file}'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-a37bfcf47296> in <cell line: 0>()
#      36             raise FileNotFoundError(f"Original embeddings file not found: '{embedding_file}'")
#      37 else:
# ---> 38     raise FileNotFoundError(f"Embeddings file not found: '{embedding_file}'")
#      39
#      40 with open(roots_file, "r", encoding="utf-8") as f:
#
# FileNotFoundError: Embeddings file not found: 'output/صلح_reduced_embeddings_with_cooccur.npy'

# %%
# Pattern Power

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import json
import os
from sklearn.manifold import TSNE
from scipy.spatial.distance import pdist, squareform
import arabic_reshaper
from bidi.algorithm import get_display
from adjustText import adjust_text

# ---------------------------
# 1. Configurations
# ---------------------------
frequency_threshold = 3  # ✅ Minimum frequency to include a root in the plot

# ---------------------------
# 2. Load Data Files
# ---------------------------

embedding_file = f"output/{specific_root}_reduced_embeddings_with_cooccur.npy"
roots_file = f"output/{specific_root}_roots_with_cooccur.json"
cooccurrence_file = f"output/{specific_root}_cooccurrence.json"
clusters_file = f"output/{specific_root}_hierarchical_clusters.json"

if not os.path.exists(embedding_file):
    raise FileNotFoundError(f"{embedding_file} not found.")
embeddings = np.load(embedding_file)
print(f"✅ Loaded embeddings: {embeddings.shape}")

with open(roots_file, "r", encoding="utf-8") as f:
    roots_list = json.load(f)

with open(cooccurrence_file, "r", encoding="utf-8") as f:
    co_data = json.load(f)

root_frequencies = {entry["co-stem"]: entry["count"] for entry in co_data.get("cooccurrences", [])}
if "total_occurrences" in co_data:
    root_frequencies[specific_root] = co_data["total_occurrences"]
    print(f"📊 Total frequency of '{specific_root}': {co_data['total_occurrences']}")
else:
    root_frequencies[specific_root] = 1
    print(f"⚠ '{specific_root}' total_occurrences not found, fallback = 1")

with open(clusters_file, "r", encoding="utf-8") as f:
    cluster_data = json.load(f)

# ---------------------------
# 3. Build Cluster Mapping
# ---------------------------
root_to_cluster = {}
for label, stems_dict in cluster_data.items():
    try:
        cluster_id = int(label.split()[1])
    except:
        cluster_id = -1
    for root in stems_dict:
        root_to_cluster[root] = cluster_id

# ---------------------------
# 4. Build Valid Root Lists
# ---------------------------
valid_roots, valid_indices, frequencies, cluster_ids = [], [], [], []
for i, root in enumerate(roots_list):
    if root in root_to_cluster and root in root_frequencies:
        valid_roots.append(root)
        valid_indices.append(i)
        frequencies.append(root_frequencies[root])
        cluster_ids.append(root_to_cluster[root])
    else:
        print(f"⚠ Skipping '{root}' — missing cluster or frequency")

if not valid_indices:
    raise ValueError("No valid roots to plot.")

# ---------------------------
# 5. t-SNE Dimensionality Reduction
# ---------------------------
selected_embeddings = embeddings[valid_indices]
distance_matrix = squareform(pdist(selected_embeddings, metric="euclidean"))

# Use previously defined perplexity if available; otherwise use default
try:
    perplexity
except NameError:
    perplexity = min(10, max(2, len(valid_indices) - 1))
print(f"Using perplexity: {perplexity}")

tsne = TSNE(
    n_components=2,
    metric="precomputed",
    init="random",
    random_state=42,
    perplexity=perplexity,
    max_iter=500
)
tsne_coords = tsne.fit_transform(distance_matrix)

# Normalize t-SNE output to [0, 1]
x = (tsne_coords[:, 0] - tsne_coords[:, 0].min()) / tsne_coords[:, 0].ptp()
y = (tsne_coords[:, 1] - tsne_coords[:, 1].min()) / tsne_coords[:, 1].ptp()
norm_coords = np.column_stack((x, y))

# ---------------------------
# 5b. Repulsion-Based Spacing Adjustment (Soft Relaxation)
# ---------------------------
def apply_min_distance_spacing(coords, min_dist=0.02, steps=10, lr=0.01):
    coords = coords.copy()
    for step in range(steps):
        for i in range(len(coords)):
            for j in range(i + 1, len(coords)):
                dx, dy = coords[i] - coords[j]
                dist = np.sqrt(dx**2 + dy**2)
                if dist < min_dist:
                    force = (min_dist - dist) * lr
                    direction = np.array([dx, dy]) / (dist + 1e-5)
                    coords[i] += direction * force
                    coords[j] -= direction * force
        # Normalize again to [0, 1] each step to keep it bounded
        coords = coords - coords.min(axis=0)
        coords = coords / coords.max(axis=0)
    return coords

norm_coords = apply_min_distance_spacing(norm_coords, min_dist=0.05, steps=20, lr=0.06)
print("✅ Coordinates adjusted with repulsion spacing.")


# ---------------------------
# 6. Filter AFTER t-SNE + Spread Enhancement
# ---------------------------
filtered_roots = []
filtered_coords = []
filtered_freqs = []
filtered_clusters = []

for i, freq in enumerate(frequencies):
    if freq >= frequency_threshold:
        filtered_roots.append(valid_roots[i])
        filtered_coords.append(norm_coords[i])
        filtered_freqs.append(freq)
        filtered_clusters.append(cluster_ids[i])

filtered_coords = np.array(filtered_coords)

# 🔹 Apply spread to improve visual distribution
spread_factor_x = 1.2
spread_factor_y = 1.2
center_x, center_y = 0.5, 0.5
filtered_coords[:, 0] = (filtered_coords[:, 0] - center_x) * spread_factor_x + center_x
filtered_coords[:, 1] = (filtered_coords[:, 1] - center_y) * spread_factor_y + center_y

# ---------------------------
# 7. Cluster Color Mapping
# ---------------------------
unique_clusters = sorted(set(filtered_clusters))
cmap = plt.get_cmap("gist_ncar", len(unique_clusters))

def luminance(color):  # perceived brightness
    r, g, b = mcolors.to_rgb(color)
    return 0.2126 * r + 0.7152 * g + 0.0722 * b

def darken(color, factor=0.7):
    return tuple(np.clip(factor * c, 0, 1) for c in mcolors.to_rgb(color))

def adjust_color(color, threshold=0.65):
    return darken(color) if luminance(color) > threshold else color

cluster_to_color = {cid: adjust_color(cmap(i)) for i, cid in enumerate(unique_clusters)}

# ---------------------------
# 8. Scatter Plot (Using Previously Set Text Parameters)
# ---------------------------
# Use previously defined base_fontsize and scale_factor if available; otherwise, default
try:
    base_fontsize
except NameError:
    base_fontsize = 8
try:
    scale_factor
except NameError:
    scale_factor = 1.2
print(f"Using base_fontsize: {base_fontsize}, scale_factor: {scale_factor}")

plt.figure(figsize=(11, 9))
texts = []

for i, (x, y) in enumerate(filtered_coords):
    root = filtered_roots[i]
    freq = filtered_freqs[i]
    cid = filtered_clusters[i]

    font_size = base_fontsize + scale_factor * freq
    label = get_display(arabic_reshaper.reshape(root))
    color = cluster_to_color.get(cid, "black")
    text = plt.text(x, y, label, fontsize=font_size, color=color, alpha=0.9)
    texts.append(text)

adjust_text(
    texts,
    only_move={'text': 'xy'},
    force_text=70,
    force_points=0.7,
    expand_text=(1.05, 2),
    expand_points=(1.05, 1.2),
    arrowprops=dict(arrowstyle="-", color='grey', lw=0.5, alpha=0.0)
)

title_ar = get_display(arabic_reshaper.reshape(specific_root))
plt.title(f"Roots Co-occurring with '{title_ar}' (freq ≥ {frequency_threshold})", fontsize=16)
plt.xlabel("t-SNE X")
plt.ylabel("t-SNE Y")
plt.grid(True)
plt.xlim(0, 1)
plt.ylim(0, 1)

output_file = f"output/{specific_root}_scatter_cooccur_roots_min{frequency_threshold}.png"
plt.savefig(output_file, dpi=600, bbox_inches="tight")
plt.show()
print(f"✅ Saved scatter plot to '{output_file}'")
# Out:
# ✅ Loaded embeddings: (648, 100)
# 📊 Total frequency of 'امن': 879
# Using perplexity: 10.0
# ✅ Coordinates adjusted with repulsion spacing.
# Using base_fontsize: 3.0, scale_factor: 0.05
# ✅ Saved scatter plot to 'output/امن_scatter_cooccur_roots_min3.png'
